# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy.stats import pearsonr
import random

warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")
data = pd.read_csv('../dataset/processed/cleaned_data.csv')
data.head()
# Out:
#                                   Movie_Title  Movie_ID     Budget  \
# 0              Jumanji: Welcome to the Jungle   2283362   90000000
# 1         Transformers: Revenge of the Fallen   1055369  200000000
# 2  Star Wars: Episode VII - The Force Awakens   2488496  245000000
# 3                                  Spider-Man    145487  139000000
# 4                              Iron Man Three   1300854  200000000
#
#                                                 Cast  \
# 0  ['Dwayne Johnson', 'Karen Gillan', 'Kevin Hart...
# 1  ['Shia LaBeouf', 'Megan Fox', 'Josh Duhamel', ...
# 2  ['Daisy Ridley', 'John Boyega', 'Oscar Isaac',...
# 3  ['Tobey Maguire', 'Kirsten Dunst', 'Willem Daf...
# 4  ['Robert Downey Jr.', 'Guy Pearce', 'Gwyneth P...
#
#                                                 Crew  \
# 0  ['Scott Rosenberg', 'Erik Sommers', 'Chris McK...
# 1  ['Ehren Kruger', 'Michael Bay', 'Roberto Orci'...
# 2  ['J.J. Abrams', 'Michael Arndt', 'Lawrence Kas...
# 3  ['Sam Raimi', 'David Koepp', 'Stan Lee', 'Stev...
# 4         ['Drew Pearce', 'Stan Lee', 'Shane Black']
#
#                                              Studios  \
# 0  ['Columbia Pictures', 'Matt Tolmach Production...
# 1  ['Dreamworks Pictures', 'Paramount Pictures', ...
# 2  ['Lucasfilm', 'Bad Robot', 'Walt Disney Pictur...
# 3  ['Columbia Pictures', 'Marvel Enterprises', 'L...
# 4  ['Marvel Studios', 'Paramount Pictures', 'DMG ...
#
#                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy']
# 1  ['Action', 'Adventure', 'Sci-Fi']
# 2  ['Action', 'Adventure', 'Sci-Fi']
# 3  ['Action', 'Adventure', 'Sci-Fi']
# 4  ['Action', 'Adventure', 'Sci-Fi']
#
#                                             Keywords               Languages  \
# 0  ['jungle', 'adventurer', 'trapped in a game', ...             ['English']
# 1  ['optimus prime character', 'megatron characte...  ['English', 'Spanish']
# 2  ['crash landing', 'reboot', 'actor reprises pr...             ['English']
# 3  ['superhero', 'peter parker character', 'ben p...             ['English']
# 4  ['terrorist', 'billionaire', 'human bomb', 'ar...             ['English']
#
#            Countries Release_Data  Runtime  Gross_worldwide  Rating  \
# 0  ['United States']   2017-12-20    119.0        995339117     6.9
# 1  ['United States']   2009-06-24    149.0        836303693     5.9
# 2  ['United States']   2015-12-18    138.0       2071310218     7.8
# 3  ['United States']   2002-05-03    121.0        825025036     7.4
# 4  ['United States']   2013-05-03    130.0       1215577205     7.1
#
#    Rating_Count ListOfCertificate  Release_Year  Release_Month  Release_Day
# 0        389000         ['PG-13']          2017             12           20
# 1        412000         ['PG-13']          2009              6           24
# 2        939000         ['PG-13']          2015             12           18
# 3        827000         ['PG-13']          2002              5            3
# 4        860000         ['PG-13']          2013              5            3

# %% [markdown]
# Load multivalued attributes

# %%
import ast

cols = ['Cast', 'Genre', 'Studios', 'ListOfCertificate', 'Keywords', 'Languages', 'Countries', 'Crew']
for col in cols:
    data[col] = data[col].apply(ast.literal_eval)

# %% [markdown]
# ## Multivalued attributes with gross and count
#
# 1. Input
# - `dataframe`: Dataframe to process
# - `col_name`: Name of the column to process, `Cast`, `Genre` and `Studios` for example
#
# 2. Output
# - Output: Dataframe contains information related to the columns combined with Money and Count

# %%
def parseWithMoneyAndCount(dataframe, col_name):
    res = []
    count = []
    gross = []

    for index, record in enumerate(dataframe[col_name]):
        for x in record:
            # Save results to corresponding array
            res.append(x)
            gross.append(dataframe['Gross_worldwide'][index])
            count.append(1)

    # Make dataframe; remove duplicates and sum corresponding columns
    t1 = pd.DataFrame({col_name: res, 'Total': gross, 'Count': count})
    result1 = t1.groupby(col_name).sum()
    result1.reset_index(inplace=True)

    t2 = pd.DataFrame({col_name: res, 'Mean': gross})
    result2 = t2.groupby(col_name).mean()
    result2.reset_index(inplace=True)

    result = result1.merge(result2, on=col_name, how='inner')

    t3 = pd.DataFrame({col_name: res, 'Median': gross})
    result3 = t3.groupby(col_name).median()
    result3.reset_index(inplace=True)

    result = result.merge(result3, on=col_name, how='inner')
    return result

# %% [markdown]
# ## Brief information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8739 entries, 0 to 8738
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Movie_Title        8739 non-null   object
#  1   Movie_ID           8739 non-null   int64
#  2   Budget             8739 non-null   int64
#  3   Cast               8739 non-null   object
#  4   Crew               8739 non-null   object
#  5   Studios            8739 non-null   object
#  6   Genre              8739 non-null   object
#  7   Keywords           8739 non-null   object
#  8   Languages          8739 non-null   object
#  9   Countries          8739 non-null   object
#  10  Release_Data       8739 non-null   object
#  11  Runtime            8739 non-null   float64
#  12  Gross_worldwide    8739 non-null   int64
#  13  Rating             8739 non-null   float64
#  14  Rating_Count       8739 non-null   int64
#  15  ListOfCertificate  8739 non-null   object
#  16  Release_Year       8739 non-null   int64
#  17  Release_Month      8739 non-null   int64
#  18  Release_Day        8739 non-null   int64
# dtypes: float64(2), int64(7), object(10)
# memory usage: 1.3+ MB

# %%
data.describe()
# Out:
#            Movie_ID        Budget      Runtime  Gross_worldwide       Rating  \
# count  8.739000e+03  8.739000e+03  8739.000000     8.739000e+03  8739.000000
# mean   1.095204e+06  2.441803e+07   108.018088     7.446696e+07     6.404360
# std    1.866347e+06  3.817999e+07    19.570991     1.625488e+08     1.014871
# min    1.234900e+04  2.200000e+02    40.000000     6.300000e+01     1.300000
# 25%    1.024530e+05  2.200000e+02    95.000000     4.659441e+06     5.800000
# 50%    2.554770e+05  1.050000e+07   104.000000     1.899972e+07     6.500000
# 75%    1.241721e+06  3.000000e+07   117.000000     6.847113e+07     7.100000
# max    1.618346e+07  3.560000e+08   357.000000     2.923706e+09     9.300000
#
#        Rating_Count  Release_Year  Release_Month  Release_Day
# count  8.739000e+03   8739.000000    8739.000000  8739.000000
# mean   9.046418e+04   2000.127703       6.627989    16.071976
# std    1.771657e+05     13.755722       3.407873     8.578610
# min    0.000000e+00   1921.000000       1.000000     1.000000
# 25%    7.800000e+03   1991.000000       4.000000     9.000000
# 50%    2.800000e+04   2002.000000       7.000000    16.000000
# 75%    9.300000e+04   2011.000000      10.000000    23.000000
# max    2.700000e+06   2023.000000      12.000000    31.000000

# %% [markdown]
# ## Heatmap of Correlation Matrix, Histogram and Scatter Matrix

# %%
cols = ['Budget', 'Runtime', 'Release_Year', 'Gross_worldwide', 'Rating', 'Rating_Count', 'Release_Month']
info = data[cols]

# %%
sns.heatmap(info.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'Movie_ID'}>,
#         <AxesSubplot:title={'center':'Budget'}>,
#         <AxesSubplot:title={'center':'Runtime'}>],
#        [<AxesSubplot:title={'center':'Gross_worldwide'}>,
#         <AxesSubplot:title={'center':'Rating'}>,
#         <AxesSubplot:title={'center':'Rating_Count'}>],
#        [<AxesSubplot:title={'center':'Release_Year'}>,
#         <AxesSubplot:title={'center':'Release_Month'}>,
#         <AxesSubplot:title={'center':'Release_Day'}>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(info, figsize=(20, 12), hist_kwds={'bins': 50})
# Out:
# array([[<AxesSubplot:xlabel='Budget', ylabel='Budget'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Budget'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Budget'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Budget'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Budget'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Budget'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Budget'>],
#        [<AxesSubplot:xlabel='Budget', ylabel='Runtime'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Runtime'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Runtime'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Runtime'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Runtime'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Runtime'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Runtime'>],
#        [<AxesSubplot:xlabel='Budget', ylabel='Release_Year'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Release_Year'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Release_Year'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Release_Year'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Release_Year'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Release_Year'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Release_Year'>],
#        [<AxesSubplot:xlabel='Budget', ylabel='Gross_worldwide'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Gross_worldwide'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Gross_worldwide'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Gross_worldwide'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Gross_worldwide'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Gross_worldwide'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Gross_worldwide'>],
#        [<AxesSubplot:xlabel='Budget', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Rating'>],
#        [<AxesSubplot:xlabel='Budget', ylabel='Rating_Count'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Rating_Count'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Rating_Count'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Rating_Count'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Rating_Count'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Rating_Count'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Rating_Count'>],
#        [<AxesSubplot:xlabel='Budget', ylabel='Release_Month'>,
#         <AxesSubplot:xlabel='Runtime', ylabel='Release_Month'>,
#         <AxesSubplot:xlabel='Release_Year', ylabel='Release_Month'>,
#         <AxesSubplot:xlabel='Gross_worldwide', ylabel='Release_Month'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Release_Month'>,
#         <AxesSubplot:xlabel='Rating_Count', ylabel='Release_Month'>,
#         <AxesSubplot:xlabel='Release_Month', ylabel='Release_Month'>]],
#       dtype=object)

# %%
final = data.copy()

# %% [markdown]
# ## `Genre` analysis

# %%
genre = parseWithMoneyAndCount(data, 'Genre')
genre
# Out:
#           Genre         Total  Count          Mean       Median
# 0        Action  287642285634   1938  1.484222e+08   51895451.0
# 1     Adventure  305241107907   1559  1.957929e+08   71410636.0
# 2     Animation   87453599849    409  2.138230e+08  110387072.0
# 3     Biography   27655515725    662  4.177570e+07   13867990.0
# 4        Comedy  237569302398   3550  6.692093e+07   20706843.5
# 5         Crime   81054091794   1548  5.236052e+07   19565564.5
# 6   Documentary    3747586538    335  1.118683e+07    2334228.0
# 7         Drama  220471213272   4668  4.723034e+07   13295058.5
# 8        Family   55229617264    552  1.000537e+08   32707797.0
# 9       Fantasy   86111331002    621  1.386656e+08   38269529.0
# 10    Film-Noir       4959769     11  4.508881e+05      43024.0
# 11      History   11935923047    288  4.144418e+07   11349561.0
# 12       Horror   39792872335    735  5.413996e+07   25422088.0
# 13        Music   13002646512    387  3.359857e+07   10489617.0
# 14      Musical    5444483514    121  4.499573e+07    9680029.0
# 15      Mystery   42728597258    689  6.201538e+07   23182223.0
# 16         News      57917412      3  1.930580e+07    4606199.0
# 17   Reality-TV       1700681      1  1.700681e+06    1700681.0
# 18      Romance   73490115542   1710  4.297668e+07   14382490.5
# 19       Sci-Fi   94712538323    542  1.747464e+08   45294068.0
# 20        Sport    8450464929    268  3.153159e+07   13946404.0
# 21     Thriller   90465882301   1140  7.935604e+07   28099532.5
# 22          War    6453123744    162  3.983410e+07    9489547.0
# 23      Western    3204321031     82  3.907709e+07   11551717.0

# %%
genre.sort_values(by='Count', ascending=False, inplace=True)
genre.plot.bar(x='Genre', y='Count')
genre.sort_values(by='Mean', ascending=False, inplace=True)
genre.plot.bar(x='Genre', y='Mean', color="salmon")
genre.sort_values(by='Median', ascending=False, inplace=True)
genre.plot.bar(x='Genre', y='Median', color="salmon")
# Out:
# <AxesSubplot:xlabel='Genre'>

# %% [markdown]
# From the bar chart that the following genres generate the highest gross:
# 1. Animation
# 2. Adventure
# 3. Action
# 4. Sci-fi
# 5. Fantasy
# 6. Family
#
# Film-Noir stays at the lowest position
#
# News, though with only 1 record, is in the top 6 of the median plot

# %%
genre.sort_values(by='Count', ascending=False)
# Out:
#           Genre         Total  Count          Mean       Median
# 7         Drama  220471213272   4668  4.723034e+07   13295058.5
# 4        Comedy  237569302398   3550  6.692093e+07   20706843.5
# 0        Action  287642285634   1938  1.484222e+08   51895451.0
# 18      Romance   73490115542   1710  4.297668e+07   14382490.5
# 1     Adventure  305241107907   1559  1.957929e+08   71410636.0
# 5         Crime   81054091794   1548  5.236052e+07   19565564.5
# 21     Thriller   90465882301   1140  7.935604e+07   28099532.5
# 12       Horror   39792872335    735  5.413996e+07   25422088.0
# 15      Mystery   42728597258    689  6.201538e+07   23182223.0
# 3     Biography   27655515725    662  4.177570e+07   13867990.0
# 9       Fantasy   86111331002    621  1.386656e+08   38269529.0
# 8        Family   55229617264    552  1.000537e+08   32707797.0
# 19       Sci-Fi   94712538323    542  1.747464e+08   45294068.0
# 2     Animation   87453599849    409  2.138230e+08  110387072.0
# 13        Music   13002646512    387  3.359857e+07   10489617.0
# 6   Documentary    3747586538    335  1.118683e+07    2334228.0
# 11      History   11935923047    288  4.144418e+07   11349561.0
# 20        Sport    8450464929    268  3.153159e+07   13946404.0
# 22          War    6453123744    162  3.983410e+07    9489547.0
# 14      Musical    5444483514    121  4.499573e+07    9680029.0
# 23      Western    3204321031     82  3.907709e+07   11551717.0
# 10    Film-Noir       4959769     11  4.508881e+05      43024.0
# 16         News      57917412      3  1.930580e+07    4606199.0
# 17   Reality-TV       1700681      1  1.700681e+06    1700681.0

# %% [markdown]
# We will develop a **Genre Rank** based on Median but will ignore the film that have number of releases < 10

# %%
genre = genre[genre['Count'] > 10]
genre.sort_values(by='Median', ascending=True, inplace=True)
genre.reset_index(drop=True, inplace=True)
genreRank = dict()
for i, row in enumerate(genre['Genre']):
    genreRank[row] = i + 1
genreRank
# Out:
# {'Film-Noir': 1,
#  'Documentary': 2,
#  'War': 3,
#  'Musical': 4,
#  'Music': 5,
#  'History': 6,
#  'Western': 7,
#  'Drama': 8,
#  'Biography': 9,
#  'Sport': 10,
#  'Romance': 11,
#  'Crime': 12,
#  'Comedy': 13,
#  'Mystery': 14,
#  'Horror': 15,
#  'Thriller': 16,
#  'Family': 17,
#  'Fantasy': 18,
#  'Sci-Fi': 19,
#  'Action': 20,
#  'Adventure': 21,
#  'Animation': 22}

# %% [markdown]
# We rank the genres by the highest rank of Genre in the list of Genres(Since Genre is multivalued attributes)

# %%
def getRank(listGenre):
    max = -1
    for genre in listGenre:
        if genre not in genreRank.keys():
            continue
        if genreRank[genre] > max:
            max = genreRank[genre]
    if max != -1:
        return max
    return 0

# %%
data2 = data.copy()
data2['GenreRank'] = data2['Genre'].apply(getRank)
corr = pearsonr(data2['GenreRank'], data2['Gross_worldwide'])[0]
print('Pearsonr correlation between GenreRank and Gross: %.3f' % corr)
data2.plot.scatter(x='GenreRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsonr correlation between GenreRank and Gross: 0.289
# <AxesSubplot:xlabel='GenreRank', ylabel='Gross_worldwide'>

# %% [markdown]
# We rank the genre by total rank of Genre in the list of Genres

# %%
def getRank(listGenre):
    max = -1
    for genre in listGenre:
        if genre not in genreRank.keys():
            continue
        max += genreRank[genre]
    if max != -1:
        return max
    return 0


data2 = data.copy()
data2['GenreRank'] = data2['Genre'].apply(getRank)
corr = pearsonr(data2['GenreRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between GenreRank and Gross: %.3f' % corr)
data2.plot.scatter(x='GenreRank', y='Gross_worldwide', color='royalblue')
# Out:
# Pearsons correlation between GenreRank and Gross: 0.334
# <AxesSubplot:xlabel='GenreRank', ylabel='Gross_worldwide'>

# %% [markdown]
# We we rank the genre by average rank of Genre in the list of Genres(Since Genre is multivalued attributes)

# %%
def getRank(listGenre):
    max = 0
    for genre in listGenre:
        if genre not in genreRank.keys():
            continue
        max += genreRank[genre]
    if max == 0:
        return random.randint(1, 15)
    return max / len(listGenre)


data2 = data.copy()
data2['GenreRank'] = data2['Genre'].apply(getRank)
corr = pearsonr(data2['GenreRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between GenreRank and Gross: %.3f' % corr)
data2.plot.scatter(x='GenreRank', y='Gross_worldwide', color='royalblue')
# Out:
# Pearsons correlation between GenreRank and Gross: 0.346
# <AxesSubplot:xlabel='GenreRank', ylabel='Gross_worldwide'>

# %%
final['GenreRank'] = data2['GenreRank']

# %% [markdown]
# Now we will test the hypothesis that movie with Genre **Adventure** will have more value than other movies

# %%
data2 = data.copy()
data2['IsAdventure'] = data2['Genre'].apply(lambda x: 1 if 'Adventure' in x else 0)
corr = pearsonr(data2['IsAdventure'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between IsAdventure and Gross: %.3f' % corr)
data2.plot.scatter(x='IsAdventure', y='Gross_worldwide', color='royalblue')
# Out:
# Pearsons correlation between IsAdventure and Gross: 0.348
# <AxesSubplot:xlabel='IsAdventure', ylabel='Gross_worldwide'>

# %% [markdown]
# We will choose this one since it has high correlation of 0.366

# %%
final['IsAdventure'] = data2['IsAdventure']

# %% [markdown]
# ## Release_Day analysis

# %%
data2 = data.copy()
data2['Release_Data'] = pd.to_datetime(data2['Release_Data'], format='%Y-%m-%d')
data2 = data2.assign(WeekDay=data2['Release_Data'].dt.weekday + 2)
data2['WeekDay'].value_counts()
# Out:
# 6    7158
# 4     903
# 5     406
# 3      84
# 7      84
# 8      55
# 2      49
# Name: WeekDay, dtype: int64

# %%
data['Release_Day'].value_counts().reset_index().plot.bar(x='index', y='Release_Day')
# Out:
# <AxesSubplot:xlabel='index'>

# %%
data2['WeekDay'].value_counts().reset_index().sort_values(by='index').plot.bar(x='index', y='WeekDay')
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# Movies tend to release in Friday

# %%
data2.plot.scatter(x='WeekDay', y='Gross_worldwide', color='brown')
# Out:
# <AxesSubplot:xlabel='WeekDay', ylabel='Gross_worldwide'>

# %% [markdown]
# No linear relation

# %%
corr = pearsonr(data2['WeekDay'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between WeekDay and Gross: %.3f' % corr)
data2.plot.scatter(x='WeekDay', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between WeekDay and Gross: -0.023
# <AxesSubplot:xlabel='WeekDay', ylabel='Gross_worldwide'>

# %% [markdown]
# Hypothesis: Did movies released in Friday or Wednesday have more gross then others?

# %%
data2['IsFriWed'] = data2['WeekDay'].apply(lambda x: 1 if x in [4, 6] else 0)
corr = pearsonr(data2['IsFriWed'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between IsFriWed and Gross: %.3f' % corr)
data2.plot.scatter(x='IsFriWed', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between IsFriWed and Gross: 0.050
# <AxesSubplot:xlabel='IsFriWed', ylabel='Gross_worldwide'>

# %% [markdown]
# Not very relevant between them!

# %% [markdown]
# ## Release_Month analysis

# %% [markdown]
# Number of release by month

# %%
month = data['Release_Month'].value_counts().reset_index().sort_values(by='index', ascending=True)
month = month.rename(columns={'index': 'Month', 'Release_Month': 'ReleaseCount'})
month.plot.bar(x='Month', y='ReleaseCount', color='green')
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# How average gross depend on Release_Month and combine with Release_Year.

# %%
cols = ['Release_Month', 'Gross_worldwide']

data.plot.scatter(x='Release_Month', y='Gross_worldwide', color='green')
plt.title("Scatter plot for Release_Month and Gross")
#3
gColor = [6, 7, 12]
rColor = [1, 2, 3, 4, 5, 8, 9, 10, 11]
colorMap = dict()
for i in gColor:
    colorMap[i] = 'tab:green'
for i in rColor:
    colorMap[i] = 'tab:red'
C = colorMap
fig = plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='Release_Year', y='Gross_worldwide', hue='Release_Month', palette=C)
plt.title("How gross distributed by Month and Year")
plt.show()

# %% [markdown]
# We can see that gross tends to increase by year.

# %%
corr = pearsonr(data2['Release_Year'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between Release_Year and Gross: %.3f' % corr)
# Out:
# Pearsons correlation between Release_Year and Gross: 0.217

# %%
cols = ['Release_Month', 'Gross_worldwide']

month = data[cols]
month = month.groupby("Release_Month").median().reset_index()
#
month.plot.bar(x='Release_Month', y='Gross_worldwide')
plt.title("Median by Month")
# Out:
# Text(0.5, 1.0, 'Median by Month')

# %% [markdown]
# By Median Plot of Month and Gross. We can see that 5,6,7,12 is the month that are top month(We call special month)

# %%
def getSpecialMonth(month):
    specialMonth = [6, 7, 12]
    if month in specialMonth:
        return 1
    else:
        return 0


data2 = data.copy()
data2['SpecialMonth'] = data2['Release_Month'].apply(getSpecialMonth)
corr = pearsonr(data2['SpecialMonth'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between SpecialMonth and Gross: %.3f' % corr)
data2.plot.scatter(x='SpecialMonth', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between SpecialMonth and Gross: 0.144
# <AxesSubplot:xlabel='SpecialMonth', ylabel='Gross_worldwide'>

# %% [markdown]
# This correlation is low. We will consider by Mean instead

# %%
month = data[cols]
month = month.groupby("Release_Month").mean().reset_index()
#1
month.plot.bar(x='Release_Month', y='Gross_worldwide')
plt.title("Average by Month")
# Out:
# Text(0.5, 1.0, 'Average by Month')

# %% [markdown]
# By Mean Plot of Month and Gross. We can see that 5,6,7,11,12 is the month that are top month(We call special month)

# %%
def getSpecialMonth(month):
    specialMonth = [5, 6, 7, 11, 12]
    if month in specialMonth:
        return 1
    else:
        return 0


data2 = data.copy()
data2['SpecialMonth'] = data2['Release_Month'].apply(getSpecialMonth)
corr = pearsonr(data2['SpecialMonth'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between SpecialMonth and Gross: %.3f' % corr)
data2.plot.scatter(x='SpecialMonth', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between SpecialMonth and Gross: 0.188
# <AxesSubplot:xlabel='SpecialMonth', ylabel='Gross_worldwide'>

# %% [markdown]
# This has higher correlation so we will choose it

# %%
final['SpecialMonth'] = data2['SpecialMonth']

# %% [markdown]
# ## Budget analysis

# %%
data['Gross_worldwide'].describe()
# Out:
# count    8.739000e+03
# mean     7.446696e+07
# std      1.625488e+08
# min      6.300000e+01
# 25%      4.659441e+06
# 50%      1.899972e+07
# 75%      6.847113e+07
# max      2.923706e+09
# Name: Gross_worldwide, dtype: float64

# %% [markdown]
# Min value is 2100 $

# %%
data['Budget'].describe()
# Out:
# count    8.739000e+03
# mean     2.441803e+07
# std      3.817999e+07
# min      2.200000e+02
# 25%      2.200000e+02
# 50%      1.050000e+07
# 75%      3.000000e+07
# max      3.560000e+08
# Name: Budget, dtype: float64

# %% [markdown]
# No 0$ value Budget (Min value is 15000$)

# %% [markdown]
# Relation between Budget and Gross_worldwide

# %%
sns.lmplot(data=data, x='Budget', y='Gross_worldwide')

# %% [markdown]
# Now we will test the correlation between Budget and Gross_WorldWide

# %%
corr = pearsonr(data['Budget'], data['Gross_worldwide'])[0]
print('Pearsons correlation between Budget and Gross: %.3f' % corr)
# Out:
# Pearsons correlation between Budget and Gross: 0.744

# %% [markdown]
# Budget and Gross_worldwide correlation may perform very well in our future model

# %% [markdown]
# ## Cast Analysis

# %% [markdown]
# Hypothesis: Is Gross depend on number of actors showed on movie's imdb webpage?

# %%
data2 = data.copy()
data2['numCast'] = data2['Cast'].apply(lambda x: len(x))
corr = pearsonr(data2['numCast'], data2['Gross_worldwide'])[0]
data2['numCast'].value_counts()
# Out:
# 18    8205
# 16      65
# 17      65
# 14      57
# 15      57
# 13      44
# 12      43
# 10      36
# 11      35
# 9       26
# 8       22
# 7       16
# 6       15
# 5       12
# 1       11
# 3       11
# 4        9
# 2        6
# 0        4
# Name: numCast, dtype: int64

# %%
corr = pearsonr(data2['numCast'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between numCast and Gross: %.3f' % corr)
data2.plot.scatter(x='numCast', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between numCast and Gross: 0.056
# <AxesSubplot:xlabel='numCast', ylabel='Gross_worldwide'>

# %% [markdown]
# ->>Very low correlation
#
# Since all imdb pages tend to have more than 17 casts per page

# %% [markdown]
# Cast and average gross of the movies they cast for

# %%
cast = parseWithMoneyAndCount(data, 'Cast')
cast.sort_values(by='Count', ascending=False, inplace=True)
cast
# Out:
#                          Cast        Total  Count          Mean      Median
# 61059       Samuel L. Jackson  18675533232     83  2.250064e+08  62022014.0
# 58377          Robert De Niro   6721196080     76  8.843679e+07  46006896.5
# 49835          Morgan Freeman  10409940899     65  1.601529e+08  95943453.0
# 41451             Liam Neeson   7239989888     62  1.167740e+08  48093907.5
# 33905            John Goodman   6018978382     61  9.867178e+07  39280992.0
# ...                       ...          ...    ...           ...         ...
# 28140          Ismael Miranda      8057636      1  8.057636e+06   8057636.0
# 28141          Ismael Tunkara     24177137      1  2.417714e+07  24177137.0
# 28142             Ismat Rafat      2022771      1  2.022771e+06   2022771.0
# 28143            Ismaïl Antar     14248749      1  1.424875e+07  14248749.0
# 72798  Þrúður Kristjánsdóttir       727594      1  7.275940e+05    727594.0
#
# [72799 rows x 5 columns]

# %%
fig = plt.figure(figsize=(8, 6))
# plt.subplot(2,1,1)
data2 = cast.sort_values(by='Count', ascending=False)[0:15]
plt.bar(data=data2, x='Cast', height='Count', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.ylabel("Number movies", fontsize=20)
plt.title("Cast and Number of Movies they cast for", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Cast and Number of Movies they cast for')

# %% [markdown]
# Our data has name of 73026 casts

# %%
cast3Movies = cast[cast['Count'] < 3]
cast3Movies.sort_values(by='Median', ascending=False, inplace=True)
cast3Movies
# Out:
#                       Cast       Total  Count          Mean        Median
# 62100  Sean Patrick Murphy  2923706026      1  2.923706e+09  2.923706e+09
# 29607   James Patrick Pitt  2923706026      1  2.923706e+09  2.923706e+09
# 61967   Sean Anthony Moran  2923706026      1  2.923706e+09  2.923706e+09
# 38049        Kelly Kilgour  2923706026      1  2.923706e+09  2.923706e+09
# 30492          Jason Whyte  2923706026      1  2.923706e+09  2.923706e+09
# ...                    ...         ...    ...           ...           ...
# 5594           Audrey Betz          63      1  6.300000e+01  6.300000e+01
# 22425     Frank Balderrama          63      1  6.300000e+01  6.300000e+01
# 21280   Estelita Rodriguez          63      1  6.300000e+01  6.300000e+01
# 22754         Fred Aldrich          63      1  6.300000e+01  6.300000e+01
# 23852          George Bell          63      1  6.300000e+01  6.300000e+01
#
# [61071 rows x 5 columns]

# %% [markdown]
# 38972 Casts with lower than 3 movies cast for and some people with very high Median Value
#
# It will cause problem of not reliable rank when we try to develop a rank system is this type of fields

# %%
fig = plt.figure(figsize=(8, 6))
# plt.subplot(2,1,1)
data2 = cast.sort_values(by='Total', ascending=False)[0:20]
plt.bar(data=data2, x='Cast', height='Total', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.ylabel("Total Gross", fontsize=15)
plt.title("Cast and Total Gross of Movies they cast for", fontsize=15)
fig = plt.figure(figsize=(8, 6))
# plt.subplot(2,1,2)
data3 = cast.sort_values(by='Mean', ascending=False)[0:20]
plt.bar(data=data3, x='Cast', height='Mean', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Cast and Average Gross of Movies they cast for", fontsize=15)
plt.xlabel("Cast", fontsize=15)
plt.ylabel("Average Gross", fontsize=15)

fig = plt.figure(figsize=(8, 6))
data3 = cast.sort_values(by='Median', ascending=False)[0:20]
plt.bar(data=data3, x='Cast', height='Median', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Cast and Median Gross of Movies they cast for", fontsize=15)
plt.xlabel("Cast", fontsize=15)
plt.ylabel("Median Gross", fontsize=15)
plt.show()

# %% [markdown]
# Those casts name is not very well-known. **Jason Whyte** and **Sean Anthony Moran** is casts with only 1 movies attended

# %% [markdown]
# Now we will develop a rank system for cast (Find top leader casts)
#
# The number of movies they cast for must larger then 5 movies

# %%
cast = parseWithMoneyAndCount(data, 'Cast')
cast.sort_values(by='Count', ascending=False, inplace=True)
cast10Movies = cast[cast['Count'] > 5]
cast10Movies.sort_values(by='Mean', ascending=False, inplace=True)
cast10Movies.reset_index(drop=True, inplace=True)
cast10Movies
# Out:
#                   Cast       Total  Count          Mean       Median
# 0         Rupert Grint  7840214947      8  9.800269e+08  938398716.0
# 1       Lupita Nyong'o  8147717254      9  9.053019e+08  967724775.0
# 2     Evangeline Lilly  6211182808      7  8.873118e+08  622674139.0
# 3         Karen Gillan  9275686637     11  8.432442e+08  773350147.0
# 4              Zendaya  4985817921      6  8.309697e+08  657949726.5
# ...                ...         ...    ...           ...          ...
# 4566      Rita Taggart    19991204      6  3.331867e+06    2243077.0
# 4567        Cary Grant    18627730      6  3.104622e+06     127690.0
# 4568       Dick Cavett    30866179     10  3.086618e+06    1324483.5
# 4569       Tony Curtis    26240536      9  2.915615e+06    1400591.0
# 4570  Arsinée Khanjian    15305635      6  2.550939e+06    3003460.5
#
# [4571 rows x 5 columns]

# %%
plt.figure(figsize=(8, 6))
data3 = cast10Movies.sort_values(by='Mean', ascending=False)[0:25]
plt.bar(data=data3, x='Cast', height='Mean', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Cast and Average Gross of Movies they cast for", fontsize=15)
plt.xlabel("Cast", fontsize=15)
plt.ylabel("Average Gross", fontsize=15)
plt.show()

# %% [markdown]
# We call them leader cast. And now move on to develop rank

# %%
cast10Movies.sort_values(by='Mean', ascending=True, inplace=True)
castRank = dict()
for i, row in enumerate(cast10Movies['Cast']):
    castRank[row] = i + 1
castRank
# Out:
# {'Arsinée Khanjian': 1,
#  'Tony Curtis': 2,
#  'Dick Cavett': 3,
#  'Cary Grant': 4,
#  'Rita Taggart': 5,
#  'Deborah Kerr': 6,
#  'John Lennon': 7,
#  'Victoria Abril': 8,
#  'Jill Schoelen': 9,
#  'Jacques Mathou': 10,
#  'Lior Ashkenazi': 11,
#  'Ramon Bieri': 12,
#  'Mink Stole': 13,
#  'Jim Metzler': 14,
#  'Kathryn Grody': 15,
#  'Blu Mankuma': 16,
#  'Richard Widmark': 17,
#  'Cheryl Ladd': 18,
#  'Traci Lind': 19,
#  'Luke Askew': 20,
#  'Patrick Huard': 21,
#  'John Cullum': 22,
#  'Ricki Lake': 23,
#  'Jack Rader': 24,
#  'Peter Eyre': 25,
#  'Gore Vidal': 26,
#  'Don McKellar': 27,
#  'Suniel Shetty': 28,
#  'Matt Keeslar': 29,
#  'Marisa Berenson': 30,
#  'Anne-Marie Johnson': 31,
#  'Humphrey Bogart': 32,
#  'Marcello Mastroianni': 33,
#  'Vrajesh Hirjee': 34,
#  'Millie Perkins': 35,
#  'John Savident': 36,
#  'Louise Latham': 37,
#  'Gordon Pinsent': 38,
#  'Jennifer Edwards': 39,
#  'Debbie Harry': 40,
#  'Ingrid Bergman': 41,
#  'Woody Strode': 42,
#  'Sandy Baron': 43,
#  'Tim Barlow': 44,
#  'Tom Burke': 45,
#  'Louise Lasser': 46,
#  'John Considine': 47,
#  'Anna Massey': 48,
#  'Amy Locane': 49,
#  'Orson Welles': 50,
#  'Niall Buggy': 51,
#  'Isabelle Adjani': 52,
#  'Albert Delpy': 53,
#  'Kerry Fox': 54,
#  'George Dickerson': 55,
#  'Ken Wahl': 56,
#  'Nastassja Kinski': 57,
#  'John Sayles': 58,
#  'Sherilyn Fenn': 59,
#  'Eric Payne': 60,
#  'Rémy Girard': 61,
#  'Dhritiman Chatterjee': 62,
#  'Danton Stone': 63,
#  'Alan Bates': 64,
#  'John F. Kennedy': 65,
#  'Gabriele Ferzetti': 66,
#  'Robert Townsend': 67,
#  'Teddy Wilson': 68,
#  'Alberta Watson': 69,
#  'Ratna Pathak Shah': 70,
#  'Steve James': 71,
#  'Tristram Jellinek': 72,
#  'Perry Lopez': 73,
#  'Ian Wolfe': 74,
#  'Kirk Douglas': 75,
#  'Michael Hordern': 76,
#  'Kieu Chinh': 77,
#  'Tony Frank': 78,
#  'John Lynch': 79,
#  'Raghuvir Yadav': 80,
#  'Antonia Rey': 81,
#  'Camille Saviola': 82,
#  'Harvey Atkin': 83,
#  'Gilda Radner': 84,
#  'Wings Hauser': 85,
#  'Prem Chopra': 86,
#  'Mukesh Tiwari': 87,
#  'Bing Crosby': 88,
#  'Jamie Tirelli': 89,
#  'Barack Obama': 90,
#  'Anne Pitoniak': 91,
#  'Divya Dutta': 92,
#  'Lesley-Anne Down': 93,
#  'William Russ': 94,
#  'Lysette Anthony': 95,
#  'Puneet Issar': 96,
#  'Charles Bronson': 97,
#  'John P. Ryan': 98,
#  'David Dukes': 99,
#  'Leonard L. Thomas': 100,
#  'Leonard Termo': 101,
#  'Wanda De Jesus': 102,
#  'Brady Corbet': 103,
#  'David Dwyer': 104,
#  'Tom Hickey': 105,
#  'Lonny Chapman': 106,
#  'Neil Young': 107,
#  'Brooke Adams': 108,
#  'Don Francks': 109,
#  'Gene Kelly': 110,
#  'Kirby Heyborne': 111,
#  'Steve Railsback': 112,
#  'Philip Akin': 113,
#  'Richard Brooks': 114,
#  'Ticky Holgado': 115,
#  'Ángela Molina': 116,
#  'William McNamara': 117,
#  'Rani Mukerji': 118,
#  'Murli Sharma': 119,
#  'Vincent Spano': 120,
#  'John Ventimiglia': 121,
#  'Tinnu Anand': 122,
#  'Manoj Bajpayee': 123,
#  'James Luisi': 124,
#  'Vidya Balan': 125,
#  'Lesley Ann Warren': 126,
#  'Peter Cook': 127,
#  'Ray Sharkey': 128,
#  'Ray McAnally': 129,
#  'Lawrence Tierney': 130,
#  'Troy Byer': 131,
#  'Ron Leibman': 132,
#  'Nigel Terry': 133,
#  'Richard Jaeckel': 134,
#  'Bill Paterson': 135,
#  'Daniel Baldwin': 136,
#  'Mariel Hemingway': 137,
#  'Robert Trebor': 138,
#  'Victoria Jackson': 139,
#  'Billy Green Bush': 140,
#  'Meg Foster': 141,
#  'Michael Gross': 142,
#  'Billy Jayne': 143,
#  'Kulbhushan Kharbanda': 144,
#  'Saif Ali Khan': 145,
#  'Sonakshi Sinha': 146,
#  'Christopher Fulford': 147,
#  'Richard Bradford': 148,
#  'Arye Gross': 149,
#  'Rachel Ward': 150,
#  'Eleanor Bron': 151,
#  'Melonie Diaz': 152,
#  'Sam Waterston': 153,
#  'Henry Silva': 154,
#  'Matthew Faison': 155,
#  'Jean-Marc Barr': 156,
#  'David Hemblen': 157,
#  'Terry Kiser': 158,
#  'Timothy Jerome': 159,
#  'David Johansen': 160,
#  'Annie Golden': 161,
#  'Brijendra Kala': 162,
#  'Molly Parker': 163,
#  'Daniel Auteuil': 164,
#  'Sandra Bernhard': 165,
#  'Johny Lever': 166,
#  'Molly Hagan': 167,
#  'Tony Roberts': 168,
#  'Kunal Kapoor': 169,
#  'Liz Torres': 170,
#  'Bill Clinton': 171,
#  'Guy Boyd': 172,
#  'Susan Tyrrell': 173,
#  'Wayne Robson': 174,
#  "John O'Leary": 175,
#  'Jack Nance': 176,
#  'Rossy de Palma': 177,
#  'Ron White': 178,
#  'Massimo Sarchielli': 179,
#  'Michael Dudikoff': 180,
#  'Pat Corley': 181,
#  'Ernest Borgnine': 182,
#  'Preity G Zinta': 183,
#  'Chris Haywood': 184,
#  'Brent Hinkley': 185,
#  'Masood Akhtar': 186,
#  'James Stewart': 187,
#  'Manoj Pahwa': 188,
#  'Hrithik Roshan': 189,
#  'Cybill Shepherd': 190,
#  'Kirron Kher': 191,
#  'Ione Skye': 192,
#  "Raymond O'Connor": 193,
#  'Alison Elliott': 194,
#  'Vipin Sharma': 195,
#  'E. Katherine Kerr': 196,
#  'Ashley Peldon': 197,
#  'Michael DeLorenzo': 198,
#  'Philippe Morier-Genoud': 199,
#  'Dennis Letts': 200,
#  'Herbert Lom': 201,
#  'Marilu Henner': 202,
#  'Vincent Kartheiser': 203,
#  'Robert Stephens': 204,
#  'Mackenzie Astin': 205,
#  'Rutanya Alda': 206,
#  'Tom Nolan': 207,
#  'Kim Hunter': 208,
#  'Darcy DeMoss': 209,
#  'Charles Lane': 210,
#  'Polly Draper': 211,
#  'Beau Starr': 212,
#  'Daniel Lapaine': 213,
#  'Catherine Deneuve': 214,
#  'Darren McGavin': 215,
#  'Panchito Gómez': 216,
#  'Stuart Margolin': 217,
#  'Santos Morales': 218,
#  'Chunky Pandey': 219,
#  'Rajpal Naurang Yadav': 220,
#  "De'aundre Bonds": 221,
#  'Susan Barnes': 222,
#  'Vic Polizos': 223,
#  'Tim Thomerson': 224,
#  'Lillete Dubey': 225,
#  'John Roselius': 226,
#  'Gary Grubbs': 227,
#  'Kane Hodder': 228,
#  'Carrie Snodgress': 229,
#  'Stephen Baldwin': 230,
#  'Paul Bartel': 231,
#  'Joe Regalbuto': 232,
#  'David Harris': 233,
#  'Victor Argo': 234,
#  'H.B. Haggerty': 235,
#  'Jordan Baker': 236,
#  'Keenan Wynn': 237,
#  'Dan Shor': 238,
#  'Harley Cross': 239,
#  'Tupac Shakur': 240,
#  'Sid Haig': 241,
#  'John Dennis Johnston': 242,
#  'Carlin Glynn': 243,
#  'Joie Lee': 244,
#  'William Morgan Sheppard': 245,
#  'Ellen David': 246,
#  "Olivia d'Abo": 247,
#  'Tuesday Weld': 248,
#  'Timothy Bottoms': 249,
#  'Meshach Taylor': 250,
#  'Eddie Albert': 251,
#  'Alex Colon': 252,
#  'Henry Fonda': 253,
#  'Lara Dutta': 254,
#  'Kareena Kapoor': 255,
#  'Ruth Sheen': 256,
#  'Isabelle Huppert': 257,
#  'Michael Schoeffling': 258,
#  'Tim Daly': 259,
#  'Sachin Khedekar': 260,
#  'Tim Woodward': 261,
#  'Mark Acheson': 262,
#  'Jonathan Silverman': 263,
#  'Neil Crone': 264,
#  'R.G. Armstrong': 265,
#  'Al Waxman': 266,
#  'Jack Wallace': 267,
#  'Joanne Baron': 268,
#  'Tico Wells': 269,
#  'Kirk Cameron': 270,
#  'Thierry Lhermitte': 271,
#  'Jason Priestley': 272,
#  'John Abraham': 273,
#  'Vincent Perez': 274,
#  'Beah Richards': 275,
#  'Jean-Claude Dreyfus': 276,
#  'John Schneider': 277,
#  'Meg Tilly': 278,
#  'John Tormey': 279,
#  'Katrin Cartlidge': 280,
#  'Matthew Laurance': 281,
#  'Louis Giambalvo': 282,
#  'Miles Chapin': 283,
#  "Tom O'Brien": 284,
#  'Stoney Jackson': 285,
#  'Craig Sheffer': 286,
#  'Lee Grant': 287,
#  'Sheeba Chaddha': 288,
#  'Louis Mustillo': 289,
#  'Royal Dano': 290,
#  'Anne-Marie Duff': 291,
#  'Erin Darke': 292,
#  'Jim Moody': 293,
#  'Anthony Holland': 294,
#  'Clayton Landey': 295,
#  'Peter Ustinov': 296,
#  'Nicholas Campbell': 297,
#  'Alan Fudge': 298,
#  'Pankaj Tripathi': 299,
#  'Natalija Nogulich': 300,
#  'Richard Benjamin': 301,
#  'Bruce Payne': 302,
#  'Joe Seneca': 303,
#  'Theodore Bikel': 304,
#  'Richard Romanus': 305,
#  'Gerrit Graham': 306,
#  'Ken Campbell': 307,
#  'William Newman': 308,
#  'Victoria Tennant': 309,
#  'Suresh Menon': 310,
#  'Iggy Pop': 311,
#  'John LaMotta': 312,
#  'Clu Gulager': 313,
#  'Kenneth McMillan': 314,
#  'Bernie McInerney': 315,
#  'Ted McGinley': 316,
#  'Rudy De Luca': 317,
#  'Ben Johnson': 318,
#  'Akshay Kumar': 319,
#  'Chloë Sevigny': 320,
#  'John Barrett': 321,
#  'Gerry Black': 322,
#  'James Cada': 323,
#  'Vlasta Vrana': 324,
#  'Harry Northup': 325,
#  'Julian Sands': 326,
#  'Mia Farrow': 327,
#  'Dennis Dun': 328,
#  'Phil Fondacaro': 329,
#  'Sylvia Miles': 330,
#  'Mary Woronov': 331,
#  'Barbara Sukowa': 332,
#  'Riteish Deshmukh': 333,
#  'Lawrence Dane': 334,
#  'Peter Arne': 335,
#  'Scott Coffey': 336,
#  'David Bowie': 337,
#  'Jason London': 338,
#  'Corbin Bernsen': 339,
#  'Chris Spencer': 340,
#  'Joseph Ragno': 341,
#  'Joanne Whalley': 342,
#  'Sarah Polley': 343,
#  'Fabrice Luchini': 344,
#  'Lee de Broux': 345,
#  'Angélica Aragón': 346,
#  'Shah Rukh Khan': 347,
#  'Govardhan Asrani': 348,
#  'Bijou Phillips': 349,
#  'Moses Gunn': 350,
#  'Cliff De Young': 351,
#  'Corey Haim': 352,
#  'Mithun Chakraborty': 353,
#  'Ken Pogue': 354,
#  'Annie McEnroe': 355,
#  'André Maranne': 356,
#  'Michael Cassidy': 357,
#  'Satish Shah': 358,
#  'Rachael Leigh Cook': 359,
#  'Bill Buell': 360,
#  'Jessica Lundy': 361,
#  'Prakash Raj': 362,
#  'Jeffrey Combs': 363,
#  'Sal Lopez': 364,
#  'Lewis Arquette': 365,
#  'Mira Sorvino': 366,
#  'Marceline Hugot': 367,
#  'Peter Vaughan': 368,
#  'Paul Butler': 369,
#  'Cliff Gorman': 370,
#  'Michael Paré': 371,
#  'Cooper Huckabee': 372,
#  'Julie Delpy': 373,
#  'Bipasha Basu': 374,
#  'Lorraine Bracco': 375,
#  'Nadim Sawalha': 376,
#  'Keenen Ivory Wayans': 377,
#  'Julie Payne': 378,
#  'Donald Pleasence': 379,
#  'Fernando Rey': 380,
#  'Richard Belzer': 381,
#  'Kim Wayans': 382,
#  'Shelley Winters': 383,
#  'Michael Tucker': 384,
#  'David de Keyser': 385,
#  'Jacqueline Bisset': 386,
#  'Faye Grant': 387,
#  'Luke Edwards': 388,
#  'Rita Moreno': 389,
#  'José Ferrer': 390,
#  'Dov Tiefenbach': 391,
#  'Mary Stuart Masterson': 392,
#  'Bill Sage': 393,
#  'Severn Darden': 394,
#  'Molly Ringwald': 395,
#  'Justin Edwards': 396,
#  'Arshad Warsi': 397,
#  'Anthony Johnson': 398,
#  'Malaika Arora': 399,
#  'Michelle Meyrink': 400,
#  'Toshirô Mifune': 401,
#  'Bert Remsen': 402,
#  'Arun Bali': 403,
#  'Laura Ramsey': 404,
#  'Julius Harris': 405,
#  'Michael Greene': 406,
#  'Charles McKeown': 407,
#  'Steven Weber': 408,
#  'Michael McKean': 409,
#  'Peter Sellers': 410,
#  'Steve Antin': 411,
#  'Ned Bellamy': 412,
#  'Peter Kwong': 413,
#  'Abhishek Bachchan': 414,
#  'John Vernon': 415,
#  'Chuck Cooper': 416,
#  'Earl Billings': 417,
#  'Fanny Ardant': 418,
#  'Gene Davis': 419,
#  'Ellis Williams': 420,
#  'Thomas Hill': 421,
#  'Michael J. Reynolds': 422,
#  'Andre Gregory': 423,
#  'Daphne Zuniga': 424,
#  'Darlanne Fluegel': 425,
#  'Trini Alvarado': 426,
#  'Christine Lahti': 427,
#  'Louis Guss': 428,
#  'Mickey Jones': 429,
#  'Arjun Rampal': 430,
#  'Christopher Malcolm': 431,
#  'Ice-T': 432,
#  'Albert Salmi': 433,
#  'Rishi Kapoor': 434,
#  'Arlen Dean Snyder': 435,
#  'Pauline Collins': 436,
#  "Milo O'Shea": 437,
#  'Frederic Forrest': 438,
#  'Tom Wright': 439,
#  'Armin Shimerman': 440,
#  'Juhi Chawla': 441,
#  'George Burns': 442,
#  'Newell Alexander': 443,
#  'Phil Davis': 444,
#  'Sean McCann': 445,
#  'T.K. Carter': 446,
#  'Naomi Campbell': 447,
#  'Shawn Hatosy': 448,
#  'Piper Laurie': 449,
#  'Judd Nelson': 450,
#  'Jane Hallaren': 451,
#  'Steve Forrest': 452,
#  'Esai Morales': 453,
#  'Jackie Shroff': 454,
#  'Maria Conchita Alonso': 455,
#  'Mia Kirshner': 456,
#  'Sonia Braga': 457,
#  'Matthew Cowles': 458,
#  'Dagmara Dominczyk': 459,
#  'Allan Arbus': 460,
#  'Joe Unger': 461,
#  'RuPaul': 462,
#  'Lee Ving': 463,
#  'Amy Wright': 464,
#  'Sy Richardson': 465,
#  'Michael V. Gazzo': 466,
#  'Sammy Davis Jr.': 467,
#  'Maggie McCarthy': 468,
#  'Jenny Wright': 469,
#  'Ann Wedgeworth': 470,
#  'John Carradine': 471,
#  'Warren Clarke': 472,
#  'Carmine Caridi': 473,
#  'James N. Harrell': 474,
#  'Danny Aiello': 475,
#  'Kathleen Wilhoite': 476,
#  'Manoj Joshi': 477,
#  'Bill Moseley': 478,
#  'George R. Robertson': 479,
#  'Suzanne Shepherd': 480,
#  'Geraldine Page': 481,
#  'Zakir Hussain': 482,
#  'Ben Gazzara': 483,
#  'Keith Carradine': 484,
#  'Robin Thomas': 485,
#  'Pawan Malhotra': 486,
#  'Mark Webber': 487,
#  'Sally Kellerman': 488,
#  'Jack Elam': 489,
#  'Ari Graynor': 490,
#  'Paul Shenar': 491,
#  'Janet MacLachlan': 492,
#  'Tony DiBenedetto': 493,
#  'Geneviève Bujold': 494,
#  'Ken Magee': 495,
#  'Joe Lisi': 496,
#  'Loyd Catlett': 497,
#  'Robert Carradine': 498,
#  'Michael Alldredge': 499,
#  'Jimmy Shergill': 500,
#  'Richard Masur': 501,
#  'Ian Bannen': 502,
#  'Laurence Olivier': 503,
#  'Richard B. Shull': 504,
#  'William Prince': 505,
#  'Karl Johnson': 506,
#  'Anthony De Longis': 507,
#  'Jon Polito': 508,
#  'Sarah Trigger': 509,
#  'Freddie Jones': 510,
#  'Sanjay Mishra': 511,
#  'James Staley': 512,
#  'David Proval': 513,
#  'Tom Villard': 514,
#  'Donald Hotton': 515,
#  'Jackie Burroughs': 516,
#  'Richard Mulligan': 517,
#  'Diana Bellamy': 518,
#  'Don Pugsley': 519,
#  'Fisher Stevens': 520,
#  'Levon Helm': 521,
#  'Bob Minor': 522,
#  'James Wilby': 523,
#  'Jan Tríska': 524,
#  'Rae Dawn Chong': 525,
#  'Anne De Salvo': 526,
#  'Tony Lo Bianco': 527,
#  'Jonathan Brandis': 528,
#  'Patricia Arquette': 529,
#  'Alia Shawkat': 530,
#  'Anna Chancellor': 531,
#  'Nicholas Rowe': 532,
#  'Manny Perez': 533,
#  'Stacy Edwards': 534,
#  'Dennis Lipscomb': 535,
#  'Vic Tayback': 536,
#  'Louise Fletcher': 537,
#  'Michael Laskin': 538,
#  'Priscilla Pointer': 539,
#  'Sam McMurray': 540,
#  'Jan Rubes': 541,
#  'Lee Wilkof': 542,
#  'James Keach': 543,
#  'Spike Lee': 544,
#  'John Dunn-Hill': 545,
#  'Kent Broadhurst': 546,
#  "Dick O'Neill": 547,
#  'Boman Irani': 548,
#  'Michael Harding': 549,
#  'Roger Aaron Brown': 550,
#  'Jane Kaczmarek': 551,
#  'Sam Wanamaker': 552,
#  'Jennifer Jason Leigh': 553,
#  'Kevin Conway': 554,
#  'Brooke Shields': 555,
#  'Raleigh Bond': 556,
#  'Blue Deckert': 557,
#  'Georgann Johnson': 558,
#  'Richard Farnsworth': 559,
#  'Billie Whitelaw': 560,
#  'Lisa Jane Persky': 561,
#  'Kajol': 562,
#  'Sonam Kapoor': 563,
#  'Method Man': 564,
#  'Bruce M. Fischer': 565,
#  'James Mason': 566,
#  'Aishwarya Rai Bachchan': 567,
#  'Pam Grier': 568,
#  'Richard Lynch': 569,
#  'Sonny Carl Davis': 570,
#  'Marsha Mason': 571,
#  'Peter Horton': 572,
#  'Steve McQueen': 573,
#  'Kabir Bedi': 574,
#  'Sully Boyar': 575,
#  'Audra Lindley': 576,
#  'Dick Van Patten': 577,
#  'Billy Beck': 578,
#  'Dana Delany': 579,
#  'Kelly Jo Minter': 580,
#  'Denise Crosby': 581,
#  'David Hart': 582,
#  'Jeremy Northam': 583,
#  'Don Hood': 584,
#  'Keith Coogan': 585,
#  'Ranbir Kapoor': 586,
#  'Ronald Guttman': 587,
#  'Stanley Brock': 588,
#  'Hart Bochner': 589,
#  'Peter Elliott': 590,
#  'William Smith': 591,
#  'Mike Moroff': 592,
#  'John Ritter': 593,
#  'Lolita Davidovich': 594,
#  'Ben Shenkman': 595,
#  'Todd Graff': 596,
#  'Bo Hopkins': 597,
#  'Mamie Gummer': 598,
#  'Ranjit Chowdhry': 599,
#  'Maria Dizzia': 600,
#  'Paul Benjamin': 601,
#  'Pauly Shore': 602,
#  'Del Close': 603,
#  'Phoebe Cates': 604,
#  'Miriam Colon': 605,
#  'Ally Sheedy': 606,
#  'Joanna Pacula': 607,
#  'Julie Warner': 608,
#  'William Ragsdale': 609,
#  'Tom Heaton': 610,
#  'Norman Fell': 611,
#  'Mike Pniewski': 612,
#  'Mel Blanc': 613,
#  'Vincent Price': 614,
#  'Ian Gomez': 615,
#  'Nicollette Sheridan': 616,
#  'Ed Grady': 617,
#  'William Traylor': 618,
#  'Mark Duplass': 619,
#  'Lindsay Crouse': 620,
#  'Dana Wheeler-Nicholson': 621,
#  'Brian McNamara': 622,
#  'John Sessions': 623,
#  'Graham Stark': 624,
#  'Paul Le Mat': 625,
#  'Kenneth Tigar': 626,
#  'Woody Allen': 627,
#  'Marvin J. McIntyre': 628,
#  'Jacqueline Fernandez': 629,
#  'Romola Garai': 630,
#  "Sean 'Diddy' Combs": 631,
#  'Eloy Casados': 632,
#  'Helen Hanft': 633,
#  'Howard Hesseman': 634,
#  'John Saxon': 635,
#  'Shelley Long': 636,
#  'Dirk Blocker': 637,
#  'David Bradley': 638,
#  'Taylor Negron': 639,
#  'Meagen Fay': 640,
#  'Judith Ivey': 641,
#  'Alexandra Holden': 642,
#  'Phyllis Somerville': 643,
#  'Nathan Davis': 644,
#  'Kevin McCarthy': 645,
#  'John Houseman': 646,
#  'George Plimpton': 647,
#  'Michael J. Pagan': 648,
#  'Marco Rodríguez': 649,
#  'Robert Vaughn': 650,
#  'Eddie Velez': 651,
#  'Damon Wayans': 652,
#  'Karen Young': 653,
#  'Farrah Fawcett': 654,
#  'Billy Barty': 655,
#  'Gillian Jacobs': 656,
#  'Haviland Morris': 657,
#  'Mark Bringelson': 658,
#  'Hill Harper': 659,
#  'William Petersen': 660,
#  "Annette O'Toole": 661,
#  'Clifford A. Pellow': 662,
#  'Irène Jacob': 663,
#  'Allan Corduner': 664,
#  'George C. Scott': 665,
#  'Mark Tandy': 666,
#  'Shelley Duvall': 667,
#  'Ken Foree': 668,
#  'Jaaved Jaaferi': 669,
#  'Wilbur Fitzgerald': 670,
#  'Emilio Estevez': 671,
#  'Brenda Vaccaro': 672,
#  'Ron Silver': 673,
#  'Edith Fields': 674,
#  'Louis Herthum': 675,
#  'Malinda Williams': 676,
#  'Talia Balsam': 677,
#  'Gene Hartline': 678,
#  'J.W. Smith': 679,
#  'Margarita Levieva': 680,
#  'Peter MacNeill': 681,
#  'Sarita Choudhury': 682,
#  'Carol Sutton': 683,
#  'Kim Greist': 684,
#  'Philip Bruns': 685,
#  'Joyce Brothers': 686,
#  'Nicholas Farrell': 687,
#  'Michael J. Pollard': 688,
#  "Dan O'Herlihy": 689,
#  'Jon Foster': 690,
#  'Lee Richardson': 691,
#  'Willard E. Pugh': 692,
#  'Rupert Graves': 693,
#  'Clifton James': 694,
#  'Rupert Frazer': 695,
#  'Robert Webber': 696,
#  'Annabella Sciorra': 697,
#  'Zulay Henao': 698,
#  'John Doe': 699,
#  'Gailard Sartain': 700,
#  'Welker White': 701,
#  'Pepe Serna': 702,
#  'James Pickens Jr.': 703,
#  'Rosanna Arquette': 704,
#  'Spalding Gray': 705,
#  'Catherine McCormack': 706,
#  'Graham Jarvis': 707,
#  'Cynthia Stevenson': 708,
#  'Lauren Hutton': 709,
#  'Paula Garcés': 710,
#  'Eddie Cibrian': 711,
#  'Ajay Devgn': 712,
#  'Helen Lloyd Breed': 713,
#  'Jeffrey Nordling': 714,
#  'Kim Delaney': 715,
#  'James Whitmore': 716,
#  'Cindy Williams': 717,
#  'Al Ruscio': 718,
#  'Kathryn Erbe': 719,
#  'Burke Byrnes': 720,
#  'Nancy Marchand': 721,
#  'Paul Sorvino': 722,
#  'Carol Kane': 723,
#  'D.W. Moffett': 724,
#  'Bill Bellamy': 725,
#  'Ray Walston': 726,
#  'Renée Taylor': 727,
#  'Amy Madigan': 728,
#  'L.Q. Jones': 729,
#  'Amy Irving': 730,
#  'Terence Kelly': 731,
#  'Al Fann': 732,
#  'Lane Smith': 733,
#  'David Byrd': 734,
#  'Kai Wulff': 735,
#  'Sushant Singh Rajput': 736,
#  'Mary J. Blige': 737,
#  'Richard Bright': 738,
#  'Kevin Heffernan': 739,
#  'Sean Young': 740,
#  'Lyman Ward': 741,
#  'Klaus Kinski': 742,
#  'Mario Van Peebles': 743,
#  'David L. Lander': 744,
#  'Joseph Maher': 745,
#  'Hanns Zischler': 746,
#  'Ebbe Roe Smith': 747,
#  'Dey Young': 748,
#  'Cindy Pickett': 749,
#  'Faye Dunaway': 750,
#  'Frank Adonis': 751,
#  'Annabeth Gish': 752,
#  'Joan Chen': 753,
#  'Charles Levin': 754,
#  'Roberto Sosa': 755,
#  'Brett Rice': 756,
#  'James Eckhouse': 757,
#  'Warren Oates': 758,
#  'Arthur J. Nascarella': 759,
#  'Chelsea Field': 760,
#  'Tim Ware': 761,
#  "Ryan O'Neal": 762,
#  'Karina Arroyave': 763,
#  'Katrina Kaif': 764,
#  'Nancy Allen': 765,
#  'Tom Savini': 766,
#  'Dudley Moore': 767,
#  'Joe Santos': 768,
#  'Lauren London': 769,
#  'Jack Thibeau': 770,
#  'Andrew Robinson': 771,
#  "Michael O'Keefe": 772,
#  'James Biberi': 773,
#  'Obba Babatundé': 774,
#  'Gregory Walcott': 775,
#  'Todd Allen': 776,
#  'Gregory Hines': 777,
#  'Andrew McCarthy': 778,
#  'George Coe': 779,
#  'Peter Bromilow': 780,
#  'Darrell Larson': 781,
#  'Abhinay Raj Singh': 782,
#  'Om Puri': 783,
#  'Sheri Moon Zombie': 784,
#  'Doris Roberts': 785,
#  'Schuyler Fisk': 786,
#  'John Standing': 787,
#  'Natasha Gregson Wagner': 788,
#  'Robert Miano': 789,
#  'Salman Khan': 790,
#  'Isaac Hayes': 791,
#  'Jason Beghe': 792,
#  'Kadeem Hardison': 793,
#  'Roger Cross': 794,
#  'Naushaad Abbas': 795,
#  'Beau Bridges': 796,
#  'Judy Parfitt': 797,
#  'Connie Britton': 798,
#  'Rockets Redglare': 799,
#  'Lisa Blount': 800,
#  'Max Wright': 801,
#  'Chuck Shamata': 802,
#  'Larry Flash Jenkins': 803,
#  'Jérémie Renier': 804,
#  'Chuck McCann': 805,
#  'Kaki Hunter': 806,
#  'Alan North': 807,
#  'Stephen E. Miller': 808,
#  'F. William Parker': 809,
#  'Margaret Whitton': 810,
#  'Paresh Rawal': 811,
#  'Sheila Kelley': 812,
#  'John de Lancie': 813,
#  'Woodrow Parfrey': 814,
#  'Brian Keith': 815,
#  'Sanjay Dutt': 816,
#  'David Hayman': 817,
#  'Melanie Griffith': 818,
#  'Louis Gossett Jr.': 819,
#  'Diane Ladd': 820,
#  'Helen Martin': 821,
#  'Fenella Woolgar': 822,
#  'Jerry Levine': 823,
#  'David Selby': 824,
#  'Robert Swan': 825,
#  'Mel Winkler': 826,
#  'James Gammon': 827,
#  'Candy Clark': 828,
#  'Gretchen Mol': 829,
#  'Anupam Kher': 830,
#  'J. Kenneth Campbell': 831,
#  'John Hancock': 832,
#  'Neil Ross': 833,
#  'Jacqueline Brookes': 834,
#  'Danny Webb': 835,
#  'George W. Bush': 836,
#  'John Gallagher Jr.': 837,
#  'Penelope Allen': 838,
#  'Ken Lerner': 839,
#  'John Philbin': 840,
#  'J. Smith-Cameron': 841,
#  'John Sharian': 842,
#  'Essence Atkins': 843,
#  'Alex Kendrick': 844,
#  'Christopher Curry': 845,
#  'Judy Davis': 846,
#  'Dennis Burkley': 847,
#  'Christopher Abbott': 848,
#  'John McLiam': 849,
#  'Frank Baker': 850,
#  'Juliet Stevenson': 851,
#  'George Wendt': 852,
#  'Brandon Smith': 853,
#  'Rony Clanton': 854,
#  'David Wohl': 855,
#  'Mike White': 856,
#  'Daniel Hugh Kelly': 857,
#  'Jerry Hardin': 858,
#  'Devon Sawa': 859,
#  'Ira Wheeler': 860,
#  'George Kennedy': 861,
#  'Fred Astaire': 862,
#  'Paula Jai Parker': 863,
#  "Mo'Nique": 864,
#  'Willie Nelson': 865,
#  'Bess Armstrong': 866,
#  'Peter Strauss': 867,
#  'Joe Spinell': 868,
#  'Lou Diamond Phillips': 869,
#  'Roseanne Barr': 870,
#  'Geoffrey Lewis': 871,
#  'Marc Lawrence': 872,
#  'André Dussollier': 873,
#  'Daniel Gerroll': 874,
#  'Angel David': 875,
#  "Patti D'Arbanville": 876,
#  'Edward Fox': 877,
#  'Tia Texada': 878,
#  'Matt Clark': 879,
#  'Rick Overton': 880,
#  'Michael McGrady': 881,
#  'Ellen Barkin': 882,
#  'Lynn Redgrave': 883,
#  'Dyan Cannon': 884,
#  'William Holden': 885,
#  'Bibi Besch': 886,
#  'Aidan Quinn': 887,
#  'John Terry': 888,
#  'Bo Derek': 889,
#  'Badja Djola': 890,
#  'Leslie Easterbrook': 891,
#  'Yaphet Kotto': 892,
#  'Herta Ware': 893,
#  'Maddie Corman': 894,
#  'Ajay Naidu': 895,
#  'Tamala Jones': 896,
#  'Catherine Hicks': 897,
#  'Art Hindle': 898,
#  'Bridget Fonda': 899,
#  'Eileen Ryan': 900,
#  'Ed Begley Jr.': 901,
#  'Daniel Benzali': 902,
#  'Nina Foch': 903,
#  'Raphael Sbarge': 904,
#  'Martin Savage': 905,
#  'Nicholas Guest': 906,
#  'François Chau': 907,
#  'Strother Martin': 908,
#  'Franklyn Ajaye': 909,
#  'Ernie Lively': 910,
#  'Tito Larriva': 911,
#  'Leslie Caron': 912,
#  "Terry O'Quinn": 913,
#  'Diana Scarwid': 914,
#  'Michael Currie': 915,
#  'Burt Kwouk': 916,
#  'Geoffrey Arend': 917,
#  'Burt Lancaster': 918,
#  'Lance Kinsey': 919,
#  'Melissa Sagemiller': 920,
#  'Phyllida Law': 921,
#  'Ellen Greene': 922,
#  'Lisa Eichhorn': 923,
#  'Tom Bower': 924,
#  'Amitabh Bachchan': 925,
#  'Lilyan Chauvin': 926,
#  'Sam Bottoms': 927,
#  'Ed Lauter': 928,
#  'Kari Wuhrer': 929,
#  'J.C. Quinn': 930,
#  'Thomas Jefferson Byrd': 931,
#  'Duane Martin': 932,
#  'Scott Paulin': 933,
#  'Brad Sullivan': 934,
#  'Scott Wilson': 935,
#  'Tony Plana': 936,
#  'Patrick Cranshaw': 937,
#  'Martha Higareda': 938,
#  'James Hampton': 939,
#  'Naseeruddin Shah': 940,
#  'Gena Rowlands': 941,
#  'Claire Bloom': 942,
#  'Ray Wise': 943,
#  'Billy Drago': 944,
#  'Susanna Thompson': 945,
#  'Wilfrid Hyde-White': 946,
#  'Scott Burkholder': 947,
#  'Rufus': 948,
#  'Brian Hooks': 949,
#  'Scatman Crothers': 950,
#  'Barry Primus': 951,
#  'Robert Joy': 952,
#  'Janet Carroll': 953,
#  'Sharat Saxena': 954,
#  'Randall Batinkoff': 955,
#  'Paul Reubens': 956,
#  'Ludivine Sagnier': 957,
#  'Elizabeth McGovern': 958,
#  'Graham Beckel': 959,
#  'Duncan Fraser': 960,
#  'Adam LeFevre': 961,
#  'Charles Haid': 962,
#  'Bud Cort': 963,
#  'Macy Gray': 964,
#  'Carl Lumbly': 965,
#  'Gwen McGee': 966,
#  'Martha Gehman': 967,
#  "Beverly D'Angelo": 968,
#  'Roxanne Hart': 969,
#  'Erich Anderson': 970,
#  'Felicity Huffman': 971,
#  'Wayne Grace': 972,
#  'Tom Towles': 973,
#  'Richard C. Sarafian': 974,
#  'Edward Herrmann': 975,
#  'Walter Barnes': 976,
#  'Alan Oppenheimer': 977,
#  'John Larroquette': 978,
#  'Larry B. Scott': 979,
#  'Michael Ontkean': 980,
#  'Robert Englund': 981,
#  'Erika Alexander': 982,
#  'Mark Harmon': 983,
#  'Greta Scacchi': 984,
#  'Allan Graf': 985,
#  'Christopher Lambert': 986,
#  'Steven Randazzo': 987,
#  'Dick Anthony Williams': 988,
#  'Joe Inscoe': 989,
#  'Nancy Travis': 990,
#  'John Aprea': 991,
#  'John Gielgud': 992,
#  'Aden Young': 993,
#  'Paul Mazursky': 994,
#  'Eric Bogosian': 995,
#  'Jack Warden': 996,
#  'John Witherspoon': 997,
#  'Richard Edson': 998,
#  'Allen Garfield': 999,
#  'Gary Carlos Cervantes': 1000,
#  ...}

# %% [markdown]
# Apply to data to get CastsRank. Here we total the rank value

# %%
def getCastsTeamRank(casts):
    total = 0
    for cast in casts:
        if cast not in castRank.keys():
            total += random.randint(1, 200)
            continue
        total += castRank[cast]
    return total

# %%
data2 = data.copy()
data2['CastsRank'] = data2['Cast'].apply(getCastsTeamRank)
data2['CastsRank'].value_counts()
# Out:
# 3386     4
# 1971     4
# 27937    4
# 1888     4
# 10468    4
#         ..
# 8803     1
# 1647     1
# 1967     1
# 3388     1
# 49312    1
# Name: CastsRank, Length: 7704, dtype: int64

# %%
corr = pearsonr(data2['CastsRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between CastsRank and Gross: %.3f' % corr)
data2.plot.scatter(x='CastsRank', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between CastsRank and Gross: 0.529
# <AxesSubplot:xlabel='CastsRank', ylabel='Gross_worldwide'>

# %%
final['CastsRank'] = data2['CastsRank']

# %% [markdown]
# How about we take the rank means?

# %%
def getCastsTeamRank(casts):
    length = len(casts)
    if length == 0:
        length = 1
    total = 0
    for cast in casts:
        if cast in castRank.keys():
            total += castRank[cast]
    return total / length

# %%
data2 = data.copy()
data2['CastsRank'] = data2['Cast'].apply(getCastsTeamRank)
data2['CastsRank'].value_counts()
corr = pearsonr(data2['CastsRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between CastsRank and Gross: %.3f' % corr)
data2.plot.scatter(x='CastsRank', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between CastsRank and Gross: 0.516
# <AxesSubplot:xlabel='CastsRank', ylabel='Gross_worldwide'>

# %% [markdown]
# Both are approximately identical correlation value of **0.51**

# %% [markdown]
# Now we will extract more feature That is:
# - Number of top lead actors(Actors that in the top **100**)
# - Have lead actor in high top (In top **30**)

# %% [markdown]
# **NumLeadActors**

# %%
cast10Movies.sort_values(by='Mean', ascending=False, inplace=True)
top100Cast = list(cast10Movies['Cast'][0:100])


def getNumLeadActors(casts):
    total = 0
    for cast in casts:
        if cast in top100Cast:
            total += 1
    return total


data2 = data.copy()
data2['NumLeadActors'] = data2['Cast'].apply(getNumLeadActors)
data2['NumLeadActors'].value_counts()
# Out:
# 0     7977
# 1      579
# 2       95
# 3       32
# 4       20
# 5       14
# 6        9
# 8        6
# 7        3
# 9        2
# 12       1
# 11       1
# Name: NumLeadActors, dtype: int64

# %%
corr = pearsonr(data2['NumLeadActors'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between NumLeadActors and Gross: %.3f' % corr)
data2.plot.scatter(x='NumLeadActors', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between NumLeadActors and Gross: 0.594
# <AxesSubplot:xlabel='NumLeadActors', ylabel='Gross_worldwide'>

# %%
final['NumLeadActors'] = data2['NumLeadActors']

# %% [markdown]
# HasTop30Actors

# %%
cast10Movies.sort_values(by='Mean', ascending=False, inplace=True)
top50Cast = list(cast10Movies['Cast'][0:50])


def getHasTop30Actors(casts):
    for cast in casts:
        if cast in top50Cast:
            return 1
    return 0


data2 = data.copy()
data2['HasTop50Actors'] = data2['Cast'].apply(getHasTop30Actors)
corr = pearsonr(data2['HasTop50Actors'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between HasTop50Actors and Gross: %.3f' % corr)
data2.plot.scatter(x='HasTop50Actors', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between HasTop50Actors and Gross: 0.345
# <AxesSubplot:xlabel='HasTop50Actors', ylabel='Gross_worldwide'>

# %%
final['HasTop50Actors'] = data2['HasTop50Actors']

# %% [markdown]
# ## Crew analysis

# %% [markdown]
# Hypothesis: Does revenue depend on number of crews appear on movie's imdb website?

# %%
data2 = data.copy()
data2['NumCrews'] = data2['Crew'].apply(lambda x: len(x))
corr = pearsonr(data2['NumCrews'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between NumCrews and Gross: %.3f' % corr)
data2.plot.scatter(x='NumCrews', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between NumCrews and Gross: 0.187
# <AxesSubplot:xlabel='NumCrews', ylabel='Gross_worldwide'>

# %%
final['NumCrews'] = data2['NumCrews']

# %%
crew = parseWithMoneyAndCount(data, 'Crew')
crew.sort_values(by='Count', ascending=False)
# Out:
#                     Crew        Total  Count          Mean       Median
# 10642        Woody Allen   1192009627     43  2.772115e+07   14792779.0
# 1867      Clint Eastwood   3458418335     38  9.101101e+07   53572298.0
# 9553        Stephen King   1964060493     37  5.308272e+07   24361867.0
# 9705    Steven Spielberg  10848145875     34  3.190631e+08  288074136.5
# 5170         John Hughes   2931431168     33  8.883125e+07   49944325.0
# ...                  ...          ...    ...           ...          ...
# 4399    James Lineberger     35856053      1  3.585605e+07   35856053.0
# 4398   James Leo Herlihy     44801177      1  4.480118e+07   44801177.0
# 4397     James Lee Burke      5009305      1  5.009305e+06    5009305.0
# 4396   James Lee Barrett    126737428      1  1.267374e+08  126737428.0
# 10772     Óskar Jónasson     96262212      1  9.626221e+07   96262212.0
#
# [10773 rows x 5 columns]

# %% [markdown]
# Number of movies each crew participate in

# %%
crew.sort_values(by='Count', ascending=False)[0:20].plot.bar(x='Crew', y='Count', color='green')
# Out:
# <AxesSubplot:xlabel='Crew'>

# %%
crew.sort_values(by='Mean', ascending=False)[0:20]
# Out:
#                    Crew        Total  Count          Mean        Median
# 4995          Joe Russo   6851950961      5  1.370390e+09  1.155046e+09
# 631       Anthony Russo   6851950961      5  1.370390e+09  1.155046e+09
# 5378          Jon Watts   3933942031      3  1.311314e+09  1.131928e+09
# 4992    Joe Robert Cole   2208008273      2  1.104004e+09  1.104004e+09
# 9478           Stan Lee  17532463572     16  1.095779e+09  9.069290e+08
# 5513        Josh Cooley   1073841394      1  1.073841e+09  1.073841e+09
# 5187         John Knoll   1058682142      1  1.058682e+09  1.058682e+09
# 3034       Eric Guillon   1034800131      1  1.034800e+09  1.034800e+09
# 10343  Victoria Strouse   1029266989      1  1.029267e+09  1.029267e+09
# 3091       Erik Sommers   4983925034      5  9.967850e+08  9.953391e+08
# 4751       Jennifer Lee   2870899858      3  9.569666e+08  1.284541e+09
# 7200    Michael Waldron    955775804      1  9.557758e+08  9.557758e+08
# 1126       Brad Ableson    939628210      1  9.396282e+08  9.396282e+08
# 8185      Pierre Coffin   3708168783      4  9.270422e+08  1.002783e+09
# 4216       J.K. Rowling   9716065693     11  8.832787e+08  9.256684e+08
# 6313         Lori Forte    877244782      1  8.772448e+08  8.772448e+08
# 6005         Kyle Balda   3483056319      4  8.707641e+08  9.872142e+08
# 10681            Yi Liu    870325439      1  8.703254e+08  8.703254e+08
# 4921            Jing Wu    870325439      1  8.703254e+08  8.703254e+08
# 8246           Qun Dong    870325439      1  8.703254e+08  8.703254e+08

# %% [markdown]
# There are lots writers and directors who participate only in few movies

# %%
releases4crew = crew[crew['Count'] > 4]
releases4crew.sort_values(by='Mean', ascending=False)[0:20]
# Out:
#                     Crew        Total  Count          Mean        Median
# 631        Anthony Russo   6851950961      5  1.370390e+09  1.155046e+09
# 4995           Joe Russo   6851950961      5  1.370390e+09  1.155046e+09
# 9478            Stan Lee  17532463572     16  1.095779e+09  9.069290e+08
# 3091        Erik Sommers   4983925034      5  9.967850e+08  9.953391e+08
# 4216        J.K. Rowling   9716065693     11  8.832787e+08  9.256684e+08
# 9563     Stephen McFeely   8663080601     10  8.663081e+08  5.322244e+08
# 1765  Christopher Markus   9408093716     11  8.552812e+08  6.447831e+08
# 1666       Chris McKenna   5014818919      6  8.358032e+08  8.090066e+08
# 8526          Rick Jaffa   5725972781      7  8.179961e+08  4.907198e+08
# 2485         David Yates   6428778860      8  8.035974e+08  8.742817e+08
# 1894     Colin Trevorrow   3993003224      5  7.986006e+08  1.001978e+09
# 6161         Lee Unkrich   3900374234      5  7.800748e+08  8.143371e+08
# 385        Amanda Silver   5323289701      7  7.604700e+08  4.818009e+08
# 8153     Philippa Boyens   6665263955      9  7.405849e+08  9.479443e+08
# 4329       James Cameron   9514793831     13  7.319072e+08  3.788824e+08
# 483       Andrew Stanton   5675208879      8  7.094011e+08  7.314749e+08
# 1224         Brian Lynch   4163814401      6  6.939691e+08  7.246580e+08
# 6977       Michael Arndt   3361010764      5  6.722022e+08  2.861686e+08
# 2584      Derek Connolly   4025038174      6  6.708397e+08  7.843154e+08
# 1677        Chris Renaud   3188494213      5  6.376988e+08  5.431580e+08

# %%
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.bar(data=crew.sort_values(by='Mean', ascending=False)[0:20], x='Crew', height='Mean')
plt.xticks(rotation=90)
plt.title("Mean Plot")
plt.subplot(1, 2, 2)
plt.bar(data=crew.sort_values(by='Median', ascending=False)[0:20], x='Crew', height='Median')
# crew.sort_values(by='Mean',ascending=False)[0:20].plot.bar(x='Crew',y='Mean')
plt.xticks(rotation=90)
plt.title("Median Plot")
plt.show()

# %% [markdown]
# The top seems not change very much
#
# Now we will develop rank of crew

# %%
crewRank = dict()
releases4crew = releases4crew.sort_values(by='Mean').reset_index(drop=True)
for i, row in enumerate(releases4crew['Crew']):
    crewRank[row] = i + 1
crewRank
# Out:
# {'Federico Fellini': 1,
#  'Ingmar Bergman': 2,
#  'Charles Chaplin': 3,
#  'Todd Solondz': 4,
#  'Errol Morris': 5,
#  'Warren Miller': 6,
#  'Bill Forsyth': 7,
#  'Krzysztof Piesiewicz': 8,
#  'Krzysztof Kieslowski': 9,
#  'Sally Potter': 10,
#  'Mark Monroe': 11,
#  'Louis Malle': 12,
#  'Henry James': 13,
#  'Alan Rudolph': 14,
#  'Zalman King': 15,
#  'Hanif Kureishi': 16,
#  'Atom Egoyan': 17,
#  'Naomi Foner': 18,
#  'Bille August': 19,
#  'Werner Herzog': 20,
#  'Desmond Nakano': 21,
#  'Alfred Hitchcock': 22,
#  'Agnieszka Holland': 23,
#  'Sam Peckinpah': 24,
#  'Laura Jones': 25,
#  'Billy Wilder': 26,
#  'Don Coscarelli': 27,
#  'Harold Pinter': 28,
#  'Whit Stillman': 29,
#  'Patrice Leconte': 30,
#  'Olivier Assayas': 31,
#  'Allan Scott': 32,
#  'James R. Silke': 33,
#  'Robin Bhatt': 34,
#  'Frank Cottrell Boyce': 35,
#  'Menahem Golan': 36,
#  'Michael Winterbottom': 37,
#  'John Huston': 38,
#  'Neal Jimenez': 39,
#  'Farhan Akhtar': 40,
#  'Denys Arcand': 41,
#  'Uwe Boll': 42,
#  'Eric Red': 43,
#  'J. Lee Thompson': 44,
#  'Stanley Donen': 45,
#  'Albert Brooks': 46,
#  'David Zelag Goodman': 47,
#  'Sam Firstenberg': 48,
#  'Terry Jones': 49,
#  'Bob Rafelson': 50,
#  'Monica Mcgowan Johnson': 51,
#  'Aaron Norris': 52,
#  'Anvita Dutt': 53,
#  'Oren Moverman': 54,
#  'Gérard Brach': 55,
#  'Ken Hixon': 56,
#  'Darin Scott': 57,
#  'Ruth Prawer Jhabvala': 58,
#  'Christopher Guest': 59,
#  'Susan Seidelman': 60,
#  'Michael Thomas': 61,
#  'Ken Russell': 62,
#  'Christopher Crowe': 63,
#  'E. Max Frye': 64,
#  'John Irvin': 65,
#  'Richard Fleischer': 66,
#  'David Lynch': 67,
#  'Jim Jarmusch': 68,
#  'W. Somerset Maugham': 69,
#  'Emilio Estevez': 70,
#  'Sergio Leone': 71,
#  'Albert Pyun': 72,
#  'Nicole Holofcener': 73,
#  'Anurag Kashyap': 74,
#  'Paul Schrader': 75,
#  'Mike Leigh': 76,
#  'Michael Winner': 77,
#  'Eugene Levy': 78,
#  'Bill Norton': 79,
#  'James Ivory': 80,
#  'Jérôme Tonnerre': 81,
#  'Randall Miller': 82,
#  'Michael Dowse': 83,
#  'Richard Pearce': 84,
#  'Robert Mandel': 85,
#  'John Dahl': 86,
#  'Priyadarshan': 87,
#  'Charlie Peters': 88,
#  'Jane Campion': 89,
#  'Roland Joffé': 90,
#  'Tom Ropelewski': 91,
#  'Sidney J. Furie': 92,
#  'Michael Radford': 93,
#  'Carroll Ballard': 94,
#  'John Sayles': 95,
#  'Gillian Armstrong': 96,
#  'Ulu Grosbard': 97,
#  'Fred Schepisi': 98,
#  'Davis Guggenheim': 99,
#  'Mira Nair': 100,
#  'Imtiaz Ali': 101,
#  'Tony Bill': 102,
#  'David Shaber': 103,
#  'Alan Ormsby': 104,
#  'Todd Graff': 105,
#  'David Mickey Evans': 106,
#  'Luciano Vincenzoni': 107,
#  'Ernest R. Dickerson': 108,
#  'Todd Haynes': 109,
#  'Thom Eberhardt': 110,
#  'Clive Barker': 111,
#  'Peter Yates': 112,
#  'John Briley': 113,
#  'Jacques Audiard': 114,
#  'Brian Garfield': 115,
#  'Bernardo Bertolucci': 116,
#  'Alan Bennett': 117,
#  'Christopher Cain': 118,
#  'Michael Schultz': 119,
#  'Ben Hecht': 120,
#  'John Boorman': 121,
#  'Rudy De Luca': 122,
#  'Martha Coolidge': 123,
#  'Douglas McGrath': 124,
#  'Franco Zeffirelli': 125,
#  'Stewart Raffill': 126,
#  'Phil Joanou': 127,
#  'Lars von Trier': 128,
#  'James Toback': 129,
#  'William Shakespeare': 130,
#  'Bruce Robinson': 131,
#  'Sanjay Leela Bhansali': 132,
#  'Jeff Kanew': 133,
#  'E.M. Forster': 134,
#  'Sidney Lumet': 135,
#  'Rick Rosenthal': 136,
#  'Paul Mazursky': 137,
#  'Robert Townsend': 138,
#  'Michael Haneke': 139,
#  'Mike Binder': 140,
#  'Steven Pressfield': 141,
#  'Miguel Tejada-Flores': 142,
#  'Howard Hawks': 143,
#  'Mike Figgis': 144,
#  'Andrew Fleming': 145,
#  'Susanne Bier': 146,
#  'John Frankenheimer': 147,
#  'Hal Ashby': 148,
#  'Siddharth Anand': 149,
#  'Farhad Samji': 150,
#  'John Crowley': 151,
#  'Steve Rash': 152,
#  'Daniel Petrie': 153,
#  'Richard Linklater': 154,
#  'Edward Tang': 155,
#  'Joe Camp': 156,
#  'Mark L. Lester': 157,
#  'Karan Johar': 158,
#  'Niranjan Iyengar': 159,
#  'Clifford Green': 160,
#  'Don Siegel': 161,
#  'Rohit Shetty': 162,
#  'Anees Bazmee': 163,
#  'Tim Metcalfe': 164,
#  'John R. Cherry III': 165,
#  'Robert Altman': 166,
#  'Michael Cimino': 167,
#  'Vidhu Vinod Chopra': 168,
#  'John Schlesinger': 169,
#  'Peter Bogdanovich': 170,
#  'David Rayfiel': 171,
#  'Paul Brickman': 172,
#  'Jay Presson Allen': 173,
#  'Rick Famuyiwa': 174,
#  'Yunus Sajawal': 175,
#  'David Cronenberg': 176,
#  'Billy Bob Thornton': 177,
#  'Brent Goldberg': 178,
#  'Jean-Claude Carrière': 179,
#  'Sajid': 180,
#  'Paul Dehn': 181,
#  'Martin Ritt': 182,
#  'Sean McNamara': 183,
#  "Pat O'Connor": 184,
#  'Jonathan Kaplan': 185,
#  'Howard Franklin': 186,
#  'James Carabatsos': 187,
#  'Bill Duke': 188,
#  'Jeremy Brock': 189,
#  'Blake Edwards': 190,
#  'Tom Holland': 191,
#  'Nolbert Brown Jr.': 192,
#  'Larry Gross': 193,
#  'Dan Gordon': 194,
#  'Robert Klane': 195,
#  'Neil Simon': 196,
#  'Paul Michael Glaser': 197,
#  'Dean Riesner': 198,
#  'James Bridges': 199,
#  'Dennis Shryack': 200,
#  'Miguel Arteta': 201,
#  'Sean S. Cunningham': 202,
#  'François Ozon': 203,
#  'Richard Loncraine': 204,
#  'Bill Lancaster': 205,
#  'Kevin Smith': 206,
#  'W.D. Richter': 207,
#  'Ernest Lehman': 208,
#  'Mary Agnes Donoghue': 209,
#  'Barbet Schroeder': 210,
#  'Richard Attenborough': 211,
#  'Neil LaBute': 212,
#  'Norman Jewison': 213,
#  'David Newman': 214,
#  'Jon Erwin': 215,
#  'Stephen J. Rivele': 216,
#  'William Dear': 217,
#  'Brent Maddock': 218,
#  'Hugh Hudson': 219,
#  'Ron Shelton': 220,
#  'Darryl Ponicsan': 221,
#  'Mark Pellington': 222,
#  'Larry Cohen': 223,
#  'Aditya Chopra': 224,
#  'Charlie Kaufman': 225,
#  'Gurinder Chadha': 226,
#  'Paul Mayeda Berges': 227,
#  'Nicholas Hytner': 228,
#  'Cary Solomon': 229,
#  'Chuck Konzelman': 230,
#  'Chris Matheson': 231,
#  'Brad Anderson': 232,
#  'Franklin J. Schaffner': 233,
#  'Bruce Beresford': 234,
#  'Jean-Claude Van Damme': 235,
#  'Richard Benjamin': 236,
#  'Gene Quintano': 237,
#  'John Stockwell': 238,
#  'Cheech Marin': 239,
#  'Marshall Brickman': 240,
#  'Tobe Hooper': 241,
#  'Wim Wenders': 242,
#  'Fred Dekker': 243,
#  'Kar-Wai Wong': 244,
#  'Arthur Hiller': 245,
#  'Rob Zombie': 246,
#  'Nicholas Kazan': 247,
#  'Stuart Rosenberg': 248,
#  'Matthew Robbins': 249,
#  'George A. Romero': 250,
#  'Michael Pressman': 251,
#  'Bob Clark': 252,
#  'Tommy Chong': 253,
#  'Carl Reiner': 254,
#  'Robert Benton': 255,
#  'Carl Franklin': 256,
#  'Bruce A. Evans': 257,
#  'Woody Allen': 258,
#  'Dalton Trumbo': 259,
#  'Tom Mankiewicz': 260,
#  'Pedro Almodóvar': 261,
#  'Alan Parker': 262,
#  'Nancy Dowd': 263,
#  'Neil Jordan': 264,
#  'DJ Pooh': 265,
#  'Christopher Hampton': 266,
#  'Stephen Frears': 267,
#  'Albert Magnoli': 268,
#  'Reginald Hudlin': 269,
#  'Chris Rock': 270,
#  'Leon Capetanos': 271,
#  'Jim Sheridan': 272,
#  'Michael Cristofer': 273,
#  'Kevin Macdonald': 274,
#  'Ted Kotcheff': 275,
#  'Peter Dexter': 276,
#  'Stirling Silliphant': 277,
#  'John Irving': 278,
#  'Steve Zacharias': 279,
#  'Terry George': 280,
#  'Jeremiah S. Chechik': 281,
#  'Jonathan Bernstein': 282,
#  'Alan B. McElroy': 283,
#  'Andy Breckman': 284,
#  'Neal Israel': 285,
#  'Spike Lee': 286,
#  'Raynold Gideon': 287,
#  'Stan Dragoti': 288,
#  'David Hare': 289,
#  'Walter Hill': 290,
#  'Wayne Wang': 291,
#  'Guy Hamilton': 292,
#  'Peter Straughan': 293,
#  'Dwight H. Little': 294,
#  'Norman Steinberg': 295,
#  'Michael Ritchie': 296,
#  'Irwin Winkler': 297,
#  'Lewis Teague': 298,
#  'Stephen Kendrick': 299,
#  'Simon Wincer': 300,
#  'Don Jakoby': 301,
#  'James Gray': 302,
#  'Victor Salva': 303,
#  'Steve Miner': 304,
#  'Michael Hoffman': 305,
#  'Eric Bernt': 306,
#  'Paul McGuigan': 307,
#  'Michael Lehmann': 308,
#  'John Waters': 309,
#  'Robert Getchell': 310,
#  'Anders Thomas Jensen': 311,
#  'Roman Polanski': 312,
#  'Howard Deutch': 313,
#  'James Fargo': 314,
#  'Wendell Mayes': 315,
#  'Milos Forman': 316,
#  'Herbert Ross': 317,
#  'Andrew Klavan': 318,
#  'Ice Cube': 319,
#  'John Schultz': 320,
#  'I.A.L. Diamond': 321,
#  'Abi Morgan': 322,
#  'Russell Mulcahy': 323,
#  'Dave Eggers': 324,
#  'Richard Lester': 325,
#  'Brett Leonard': 326,
#  'Bo Goldman': 327,
#  'Grégory Levasseur': 328,
#  'Francis Veber': 329,
#  'David Seltzer': 330,
#  'Harry Elfont': 331,
#  'John Guillermin': 332,
#  'Gregory Widen': 333,
#  'Mick Garris': 334,
#  'Alastair Fothergill': 335,
#  'Robert Bolt': 336,
#  'David Loughery': 337,
#  'Don Mancini': 338,
#  'John Carpenter': 339,
#  'David Mamet': 340,
#  'Vijay Krishna Acharya': 341,
#  'Donald E. Westlake': 342,
#  'Elizabeth Chandler': 343,
#  'Jerry Juhl': 344,
#  'Douglas Day Stewart': 345,
#  'John Hodge': 346,
#  'Matthew Stone': 347,
#  'Ted Demme': 348,
#  'Jonathan Lynn': 349,
#  'Buck Henry': 350,
#  'Howard Zieff': 351,
#  'Alex Kendrick': 352,
#  'Gary Goldman': 353,
#  'Joe Dante': 354,
#  'John le Carré': 355,
#  'Harold Becker': 356,
#  'Jay Chandrasekhar': 357,
#  'Lewis Colick': 358,
#  'Dick Clement': 359,
#  'Deborah Kaplan': 360,
#  'Robert Ramsey': 361,
#  'Karen Janszen': 362,
#  'Lem Dobbs': 363,
#  'Peter Hedges': 364,
#  'Thomas Rickman': 365,
#  'Billy Crystal': 366,
#  'Luis Mandoki': 367,
#  'Steve Pink': 368,
#  'Paul Thomas Anderson': 369,
#  'Ian La Frenais': 370,
#  'Mark Rydell': 371,
#  'Iain Softley': 372,
#  'Gus Van Sant': 373,
#  'Allison Burnett': 374,
#  'Charles Edward Pogue': 375,
#  'Tina Gordon': 376,
#  'Terrence Malick': 377,
#  'Sofia Coppola': 378,
#  'David Lean': 379,
#  'John Kamps': 380,
#  'Dennis Feldman': 381,
#  'Jane Austen': 382,
#  'Ken Kwapis': 383,
#  'James Ellroy': 384,
#  'Ron Underwood': 385,
#  'Peter Hyams': 386,
#  'Victor Miller': 387,
#  'Andrew Bergman': 388,
#  'John Milius': 389,
#  'Sheldon Lettich': 390,
#  'Elmore Leonard': 391,
#  'Charles Shyer': 392,
#  'Michael Moore': 393,
#  'Terry Gilliam': 394,
#  'Heywood Gould': 395,
#  'Michael Caton-Jones': 396,
#  'Adam Rifkin': 397,
#  'Steven Knight': 398,
#  'Akira Kurosawa': 399,
#  'Abhijat Joshi': 400,
#  'Mitch Glazer': 401,
#  'Don Bluth': 402,
#  'Harry Julian Fink': 403,
#  'Rita M. Fink': 404,
#  'William Friedkin': 405,
#  'Mark Neveldine': 406,
#  'Craig Bolotin': 407,
#  'Hugh Wilson': 408,
#  'Robert Towne': 409,
#  'Jean-Jacques Annaud': 410,
#  "Gavin O'Connor": 411,
#  'Kathryn Bigelow': 412,
#  'Mark Brown': 413,
#  'Andrew Birkin': 414,
#  'Joe Roth': 415,
#  'J. Mills Goodloe': 416,
#  'Brian Robbins': 417,
#  'Scott Hicks': 418,
#  'Jonathan Demme': 419,
#  'Jeannot Szwarc': 420,
#  'Stephen Hopkins': 421,
#  'Roger Kumble': 422,
#  'Walon Green': 423,
#  'Eli Roth': 424,
#  'Carol Sobieski': 425,
#  'Stuart Gordon': 426,
#  'Hal Needham': 427,
#  'Steve Martin': 428,
#  'Thomas Meehan': 429,
#  'Tom Tykwer': 430,
#  'Donald Petrie': 431,
#  'Stanley Kubrick': 432,
#  'Tom Stoppard': 433,
#  'George Tillman Jr.': 434,
#  'Ronald Harwood': 435,
#  'John G. Avildsen': 436,
#  'Ronny Yu': 437,
#  'Gary Fleder': 438,
#  'Tyler Perry': 439,
#  'Danny DeVito': 440,
#  'Robert Redford': 441,
#  'Taylor Hackford': 442,
#  'David S. Ward': 443,
#  'Mary Shelley': 444,
#  'Brian Taylor': 445,
#  'Dale Launer': 446,
#  'Joseph Ruben': 447,
#  'George Roy Hill': 448,
#  'Charles Martin Smith': 449,
#  'John Pogue': 450,
#  'Stephen King': 451,
#  'Jeff Wadlow': 452,
#  'Harris Goldberg': 453,
#  'Larry Ferguson': 454,
#  'Steven Brill': 455,
#  'John Patrick Shanley': 456,
#  'Robert King': 457,
#  'Chuck Pfarrer': 458,
#  'Sam Weisman': 459,
#  'George Gallo': 460,
#  'Caroline Thompson': 461,
#  'Randal Kleiser': 462,
#  'Tom Schulman': 463,
#  'Richard Price': 464,
#  'William Goldman': 465,
#  'Jonathan Levine': 466,
#  'Josh Stolberg': 467,
#  'Peter Hewitt': 468,
#  'Rod Daniel': 469,
#  'Thomas Carter': 470,
#  'Jay Cocks': 471,
#  'Don Roos': 472,
#  'Phil Alden Robinson': 473,
#  'John Glen': 474,
#  'Wes Craven': 475,
#  'Alexandre Aja': 476,
#  'John Badham': 477,
#  'Larry Karaszewski': 478,
#  'Mel Brooks': 479,
#  'Alex Garland': 480,
#  'Scott Alexander': 481,
#  'Albert S. Ruddy': 482,
#  'James Schamus': 483,
#  'Wes Anderson': 484,
#  'Michael Grais': 485,
#  'Francis Ford Coppola': 486,
#  'Robert Wise': 487,
#  'John Landis': 488,
#  'Hark Tsui': 489,
#  'Joseph Barbera': 490,
#  'John Whitesell': 491,
#  'John Romano': 492,
#  'Rob Reiner': 493,
#  'Andrzej Bartkowiak': 494,
#  'Les Mayfield': 495,
#  'David Webb Peoples': 496,
#  'Michel Gondry': 497,
#  'Frank Pierson': 498,
#  'James Orr': 499,
#  'Michael Apted': 500,
#  'Nick Hornby': 501,
#  'Barry Levinson': 502,
#  'Curtis Hanson': 503,
#  'Stephen Herek': 504,
#  'Roger Donaldson': 505,
#  'Jon Avnet': 506,
#  'Wesley Strick': 507,
#  'Gregory Hoblit': 508,
#  'Nick Castle': 509,
#  'Roger Michell': 510,
#  'Joe Eszterhas': 511,
#  'George Clooney': 512,
#  'Warren Beatty': 513,
#  'Peter Chelsom': 514,
#  'Pat Proft': 515,
#  'Debra Hill': 516,
#  'Greg Mottola': 517,
#  'Allen Hughes': 518,
#  'Mike Nichols': 519,
#  'Frank Oz': 520,
#  'Mike Rich': 521,
#  'Lewis Gilbert': 522,
#  'Paul Rudnick': 523,
#  'S.S. Wilson': 524,
#  'John Fusco': 525,
#  'Larry McMurtry': 526,
#  'Charles Dickens': 527,
#  'Craig Gillespie': 528,
#  'Leonard Nimoy': 529,
#  'Richard LaGravenese': 530,
#  'Alan J. Pakula': 531,
#  'Jim Henson': 532,
#  'Jason Friedberg': 533,
#  'Aaron Seltzer': 534,
#  'Lowell Ganz': 535,
#  'Penny Marshall': 536,
#  'Glen Morgan': 537,
#  'Bill Walsh': 538,
#  'Diablo Cody': 539,
#  'Babaloo Mandel': 540,
#  'Jon Amiel': 541,
#  'Hal Barwood': 542,
#  'Mark Rosenthal': 543,
#  'Malcolm D. Lee': 544,
#  'Brian De Palma': 545,
#  'Yimou Zhang': 546,
#  'Richard Maibaum': 547,
#  'Gerald Di Pego': 548,
#  'Amy Holden Jones': 549,
#  'René Goscinny': 550,
#  'Albert Uderzo': 551,
#  'Penelope Spheeris': 552,
#  'Mike White': 553,
#  'George P. Cosmatos': 554,
#  'Lasse Hallström': 555,
#  'Jean-Pierre Jeunet': 556,
#  'David Levien': 557,
#  'Brian Koppelman': 558,
#  'Michael Miner': 559,
#  'David Zucker': 560,
#  'Ann Biderman': 561,
#  'Oliver Stone': 562,
#  'Keenen Ivory Wayans': 563,
#  'Robert Harling': 564,
#  'Larry Gelbart': 565,
#  'David Gordon Green': 566,
#  'Amy Heckerling': 567,
#  'Daniel Waters': 568,
#  'Spike Jonze': 569,
#  'Pierre Morel': 570,
#  'Jim Kouf': 571,
#  'Simon Wells': 572,
#  'Kirk Jones': 573,
#  'Philip Kaufman': 574,
#  'Roger Spottiswoode': 575,
#  'Nicholas Meyer': 576,
#  'Joel Coen': 577,
#  'Ethan Coen': 578,
#  'James DeMonaco': 579,
#  'Edgar Rice Burroughs': 580,
#  'Michael Schiffer': 581,
#  'Leslie Bohem': 582,
#  'Herschel Weingrod': 583,
#  'Kunihiko Yuyama': 584,
#  'John Singleton': 585,
#  'Michael G. Wilson': 586,
#  'Danny Boyle': 587,
#  'Harold Ramis': 588,
#  'Albert Hughes': 589,
#  'Fred Wolf': 590,
#  'Michael Tolkin': 591,
#  'Satoshi Tajiri': 592,
#  'Gloria Katz': 593,
#  'Jessie Nelson': 594,
#  'Mark Steven Johnson': 595,
#  'David R. Ellis': 596,
#  'Mark Andrus': 597,
#  'David Twohy': 598,
#  'Renny Harlin': 599,
#  'James Foley': 600,
#  'Nora Ephron': 601,
#  'Jim Taylor': 602,
#  'Patrick Melton': 603,
#  'Marcus Dunstan': 604,
#  'Alexandre Dumas': 605,
#  'Allan Loeb': 606,
#  'Noah Baumbach': 607,
#  'Cameron Crowe': 608,
#  'Jeremy Leven': 609,
#  'Robin Swicord': 610,
#  'Delia Ephron': 611,
#  'Nicholas Sparks': 612,
#  'John Ridley': 613,
#  'Joel Schumacher': 614,
#  'Ted Griffin': 615,
#  'David Bowers': 616,
#  'Jim Abrahams': 617,
#  'Robert Rodriguez': 618,
#  'John Madden': 619,
#  'Kaige Chen': 620,
#  'Catherine Hardwicke': 621,
#  'Julian Fellowes': 622,
#  'Jeb Stuart': 623,
#  'Peter Tolan': 624,
#  'Andrew Davis': 625,
#  'Anthony Minghella': 626,
#  'Daniel Pyne': 627,
#  'George Cukor': 628,
#  'Terry Hayes': 629,
#  'William D. Wittliff': 630,
#  'Peter Weir': 631,
#  'Martin Scorsese': 632,
#  'Tom S. Parker': 633,
#  'Ted Tally': 634,
#  'Jason Reitman': 635,
#  'Marlon Wayans': 636,
#  'Willard Huyck': 637,
#  'Gary Winick': 638,
#  'John Hughes': 639,
#  'Wilfred Jackson': 640,
#  'Steve Carr': 641,
#  'Roger Avary': 642,
#  'Mark Waters': 643,
#  'Nick Cassavetes': 644,
#  'Clint Eastwood': 645,
#  'Steven Soderbergh': 646,
#  'Jerry Belson': 647,
#  'Kenneth Lonergan': 648,
#  'Karen McCullah': 649,
#  'Kirsten Smith': 650,
#  'Clyde Geronimi': 651,
#  'Arthur Conan Doyle': 652,
#  'Roald Dahl': 653,
#  'Lee Tamahori': 654,
#  'Sydney Pollack': 655,
#  'Richard Matheson': 656,
#  'Michael H. Weber': 657,
#  'Scott Neustadter': 658,
#  'Frank Darabont': 659,
#  'George Miller': 660,
#  'Edward Neumeier': 661,
#  'Christopher Landon': 662,
#  'Steven Rogers': 663,
#  'Andy Fickman': 664,
#  'Joel Cohen': 665,
#  'Michael Mann': 666,
#  'William Osborne': 667,
#  'Brian Helgeland': 668,
#  'Stieg Larsson': 669,
#  'Stephen Gaghan': 670,
#  'William Hanna': 671,
#  'Justin Haythe': 672,
#  'Ron Bass': 673,
#  'Frank Miller': 674,
#  'Johnny Knoxville': 675,
#  'Dominic Sena': 676,
#  'Agatha Christie': 677,
#  'Garry Marshall': 678,
#  'Barry W. Blaustein': 679,
#  'Len Blum': 680,
#  'Phillip Noyce': 681,
#  'Ed Decter': 682,
#  'Lawrence Konner': 683,
#  'Joe Wright': 684,
#  'Glenn Ficarra': 685,
#  'Darren Aronofsky': 686,
#  'John Thomas': 687,
#  'Evan Goldberg': 688,
#  'David Dobkin': 689,
#  'Gregory Poirier': 690,
#  'Hossein Amini': 691,
#  'Bobby Farrelly': 692,
#  'Audrey Wells': 693,
#  'Juliet Snowden': 694,
#  'Joe Carnahan': 695,
#  'Judd Apatow': 696,
#  'Harald Zwart': 697,
#  'Kevin Williamson': 698,
#  'Dennis Lehane': 699,
#  'Nat Mauldin': 700,
#  'Ben Stiller': 701,
#  'Paul Weitz': 702,
#  'Simon Pegg': 703,
#  'Mario Puzo': 704,
#  'Emile Ardolino': 705,
#  'David O. Russell': 706,
#  'Leslie Dixon': 707,
#  'Wolfgang Reitherman': 708,
#  'Gabriele Muccino': 709,
#  'Jason Segel': 710,
#  'John Grisham': 711,
#  'Maya Forbes': 712,
#  'Marc Lawrence': 713,
#  'Tarsem Singh': 714,
#  'Ian Fleming': 715,
#  'Brian Levant': 716,
#  'Jeffrey Reddick': 717,
#  'Dan Aykroyd': 718,
#  'John J. Strauss': 719,
#  'Tim Story': 720,
#  'Kurt Wimmer': 721,
#  'Richard Marquand': 722,
#  'D.J. Caruso': 723,
#  'Seth Rogen': 724,
#  'Daniel Petrie Jr.': 725,
#  'Edward Zwick': 726,
#  'Kevin Reynolds': 727,
#  'Paul Attanasio': 728,
#  'Robert Nelson Jacobs': 729,
#  'John McTiernan': 730,
#  'Steven E. de Souza': 731,
#  'Carl Gottlieb': 732,
#  'Jez Butterworth': 733,
#  'P.J. Hogan': 734,
#  'Gavin Hood': 735,
#  'Luc Besson': 736,
#  'Robert Luketic': 737,
#  'Timothy Harris': 738,
#  'Alec Sokolow': 739,
#  'Leigh Whannell': 740,
#  'Antoine Fuqua': 741,
#  'Ken Kaufman': 742,
#  'David Frankel': 743,
#  'Mick Jackson': 744,
#  'John Cleese': 745,
#  'Eric Heisserer': 746,
#  'Will Ferrell': 747,
#  'Jim Thomas': 748,
#  'Vijayendra Prasad': 749,
#  'Andrew Niccol': 750,
#  'Martin Brest': 751,
#  'Aaron Sorkin': 752,
#  'Adrian Lyne': 753,
#  'Pierre Boulle': 754,
#  'David Berenbaum': 755,
#  'William Peter Blatty': 756,
#  'Peter Segal': 757,
#  'Ang Lee': 758,
#  'John Requa': 759,
#  'Richard Donner': 760,
#  'Nancy Meyers': 761,
#  'Boaz Yakin': 762,
#  'John Gatins': 763,
#  'J.F. Lawton': 764,
#  'Shawn Wayans': 765,
#  'Aline Brosh McKenna': 766,
#  'Menno Meyjes': 767,
#  'Guillermo del Toro': 768,
#  'Andrew Davies': 769,
#  'Peter Farrelly': 770,
#  'Karey Kirkpatrick': 771,
#  'Bruce Joel Rubin': 772,
#  'Matt Manfredi': 773,
#  'Chuck Russell': 774,
#  'Neil Gaiman': 775,
#  'Paul Hogan': 776,
#  'John Morris': 777,
#  'Michael Petroni': 778,
#  'Jeffrey Boam': 779,
#  'John Moore': 780,
#  'Charles Leavitt': 781,
#  'Dennis Dugan': 782,
#  'Donald E. Stewart': 783,
#  'Susannah Grant': 784,
#  'Phil Hay': 785,
#  'Michael Ferris': 786,
#  'Ivan Reitman': 787,
#  'Duane Adler': 788,
#  'Alexander Payne': 789,
#  'Andrew Kevin Walker': 790,
#  'Adam Shankman': 791,
#  "Dan O'Bannon": 792,
#  'Jerry Zucker': 793,
#  'Tony Scott': 794,
#  'Andy Tennant': 795,
#  'Peter Laird': 796,
#  'Philip K. Dick': 797,
#  'Sean Anders': 798,
#  'Ben Affleck': 799,
#  'Rob Cohen': 800,
#  'Oren Peli': 801,
#  'Emma Thompson': 802,
#  'Mark Frost': 803,
#  'Anne Fletcher': 804,
#  'Robert Mark Kamen': 805,
#  'William Nicholson': 806,
#  'John Brancato': 807,
#  'Paul W.S. Anderson': 808,
#  'Bill Collage': 809,
#  'Adam Cooper': 810,
#  'Greg Berlanti': 811,
#  'Gene Roddenberry': 812,
#  'John Lee Hancock': 813,
#  'Billy Ray': 814,
#  'Rich Wilkes': 815,
#  'Frank Coraci': 816,
#  'Ed Solomon': 817,
#  'Graham Yost': 818,
#  'Nicholas Stoller': 819,
#  'Richard Wenk': 820,
#  'Betty Thomas': 821,
#  'Eddie Murphy': 822,
#  'Peter Benchley': 823,
#  'Peter Berg': 824,
#  'Seth Gordon': 825,
#  'Alvin Sargent': 826,
#  'Ronald Shusett': 827,
#  'Tim Hill': 828,
#  'Marshall Herskovitz': 829,
#  'Dana Fox': 830,
#  'Alejandro G. Iñárritu': 831,
#  'Paul Verhoeven': 832,
#  'Robert Rodat': 833,
#  'James L. Brooks': 834,
#  'Marc Silverstein': 835,
#  'Abby Kohn': 836,
#  'Will Gluck': 837,
#  'William Monahan': 838,
#  'Leo Benvenuti': 839,
#  'David Ayer': 840,
#  'Robert Gordon': 841,
#  'J.M. Barrie': 842,
#  'Kenneth Branagh': 843,
#  'Danilo Bach': 844,
#  'Tom McCarthy': 845,
#  'John Hamburg': 846,
#  'Doug Liman': 847,
#  'Damien Chazelle': 848,
#  'Alex Proyas': 849,
#  'Sylvester Stallone': 850,
#  'Steven Zaillian': 851,
#  'James V. Hart': 852,
#  'Quentin Tarantino': 853,
#  'Eric Roth': 854,
#  'Tim Herlihy': 855,
#  'Dan Gilroy': 856,
#  'Gary Ross': 857,
#  'James Vanderbilt': 858,
#  'Brad Silberling': 859,
#  'Jonathan Mostow': 860,
#  'Denis Villeneuve': 861,
#  'Thomas Harris': 862,
#  'Scott Frank': 863,
#  'Mike Myers': 864,
#  'Matthew Michael Carnahan': 865,
#  'Jaume Collet-Serra': 866,
#  'Don Rhymer': 867,
#  'Steve Koren': 868,
#  'Scott Moore': 869,
#  'Ol Parker': 870,
#  'Timothy Dowling': 871,
#  'Mike Newell': 872,
#  'Matt Sazama': 873,
#  'Burk Sharpless': 874,
#  'Scot Armstrong': 875,
#  'Chad Hayes': 876,
#  'Hayao Miyazaki': 877,
#  'Steve Conrad': 878,
#  'Peter Baynham': 879,
#  'Ron Howard': 880,
#  'Edgar Wright': 881,
#  'David Benioff': 882,
#  'Jon M. Chu': 883,
#  'Gerry Swallow': 884,
#  'Ridley Scott': 885,
#  'Craig Pearce': 886,
#  'Martin Campbell': 887,
#  'Adam Sandler': 888,
#  'Skip Woods': 889,
#  'Adam McKay': 890,
#  'Joe Johnston': 891,
#  'Wolfgang Petersen': 892,
#  'Lorne Cameron': 893,
#  'Stephen Sommers': 894,
#  'James Mangold': 895,
#  'J. David Stem': 896,
#  'Paul Haggis': 897,
#  'Jay Roach': 898,
#  'Steve Oedekerk': 899,
#  'George Nolfi': 900,
#  'Paul Feig': 901,
#  'Bob Gale': 902,
#  'Robert Schwentke': 903,
#  'Jonathan Hensleigh': 904,
#  'Marc Forster': 905,
#  'John Woo': 906,
#  'Jon Lucas': 907,
#  'Thomas Lennon': 908,
#  'Simon West': 909,
#  'Tom Clancy': 910,
#  'Scott Derrickson': 911,
#  'Randall Wallace': 912,
#  'Kevin Jarre': 913,
#  'Louis Leterrier': 914,
#  'Dave Callaham': 915,
#  'Len Wiseman': 916,
#  'McG': 917,
#  'Mike Werb': 918,
#  'Robert Ben Garant': 919,
#  'Raja Gosnell': 920,
#  'Craig Mazin': 921,
#  'Peter Morgan': 922,
#  'Baz Luhrmann': 923,
#  'Tom Shadyac': 924,
#  'Will Davies': 925,
#  'Simon Beaufoy': 926,
#  'David Lindsay-Abaire': 927,
#  'Jay Scherick': 928,
#  'Chris Columbus': 929,
#  'Tommy Swerdlow': 930,
#  'Dan Fogelman': 931,
#  'David N. Weiss': 932,
#  'Jon Turteltaub': 933,
#  'David Fincher': 934,
#  'Brett Ratner': 935,
#  'Jonathan Liebesman': 936,
#  'Tony Gilroy': 937,
#  'Robert Zemeckis': 938,
#  'Barry Sonnenfeld': 939,
#  'Mark Millar': 940,
#  'Paul Greengrass': 941,
#  'Shane Black': 942,
#  'F. Gary Gray': 943,
#  'Tim Burton': 944,
#  'Joe Shuster': 945,
#  'Richard Curtis': 946,
#  'Marianne Wibberley': 947,
#  'Mel Gibson': 948,
#  'Shawn Levy': 949,
#  'Laeta Kalogridis': 950,
#  'Erich Hoeber': 951,
#  'Jon Hoeber': 952,
#  'Robert Ludlum': 953,
#  'Tab Murphy': 954,
#  'David Koepp': 955,
#  'Akiva Goldsman': 956,
#  'William Broyles Jr.': 957,
#  'Lilly Wachowski': 958,
#  'Lana Wachowski': 959,
#  'Jonathan Goldstein': 960,
#  'Melissa Mathison': 961,
#  'Alfred Gough': 962,
#  'Dean Devlin': 963,
#  'Cormac Wibberley': 964,
#  'M. Night Shyamalan': 965,
#  'Mark Bomback': 966,
#  'Matthew Vaughn': 967,
#  'Lawrence Kasdan': 968,
#  'Marc Webb': 969,
#  'Jeffrey Price': 970,
#  'Jerry Siegel': 971,
#  'Mike Mitchell': 972,
#  'Jan de Bont': 973,
#  'John Francis Daley': 974,
#  'Ruben Fleischer': 975,
#  'Sam Raimi': 976,
#  'Brad Peyton': 977,
#  'Bill Condon': 978,
#  'Michael McCullers': 979,
#  'Michael Green': 980,
#  'John Logan': 981,
#  'Peyton Reed': 982,
#  'Mark Burton': 983,
#  'Evan Spiliotopoulos': 984,
#  'Matt Reeves': 985,
#  'Alfonso Cuarón': 986,
#  'Christopher Miller': 987,
#  'Drew Goddard': 988,
#  'Darren Lemke': 989,
#  'Guy Ritchie': 990,
#  'George Clayton Johnson': 991,
#  'Charles Perrault': 992,
#  'Jane Goldman': 993,
#  'Ron Clements': 994,
#  'John August': 995,
#  'Kelly Asbury': 996,
#  'James Gunn': 997,
#  'Scott Silver': 998,
#  'Phil Lord': 999,
#  'David S. Goyer': 1000,
#  ...}

# %%
len(crewRank)
# Out:
# 1104

# %% [markdown]
# Now we will rank the movies based on crew team rank

# %%
import random


def getCrewsTeamRank(crews):
    total = 0
    for crew in crews:
        if crew not in crewRank.keys():
            total += random.randint(1, 100)
            continue
        total += crewRank[crew]
    return total


data2 = data.copy()
data2['crewsTeamRank'] = data2['Crew'].apply(getCrewsTeamRank)
data2['crewsTeamRank'].value_counts()
# Out:
# 258     39
# 96      35
# 109     30
# 100     29
# 67      28
#         ..
# 2157     1
# 1734     1
# 372      1
# 1761     1
# 3350     1
# Name: crewsTeamRank, Length: 2154, dtype: int64

# %%
corr = pearsonr(data2['crewsTeamRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between crewsTeamRank and Gross: %.3f' % corr)
data2.plot.scatter(x='crewsTeamRank', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between crewsTeamRank and Gross: 0.559
# <AxesSubplot:xlabel='crewsTeamRank', ylabel='Gross_worldwide'>

# %%
final['crewsTeamRank'] = data2['crewsTeamRank']

# %% [markdown]
# Result correlation:
# - By mean total rank: 0.551
# - By mean mean rank: 0.516
# - By median total rank : 0.535
# - By median mean rank : 0.470

# %% [markdown]
# Now consider number of crew in top 150 for each movie

# %%
releases4crew.sort_values(by='Mean', ascending=False, inplace=True)
top150Crew = list(releases4crew['Crew'][0:150])


def getNumTopCrew(crews):
    total = 0
    for crew in crews:
        if crew in top150Crew:
            total += 1
    return total


data2 = data.copy()
data2['NumTopCrew'] = data2['Crew'].apply(getNumTopCrew)
data2['NumTopCrew'].value_counts()
# Out:
# 0    7896
# 1     564
# 2     169
# 3      86
# 4      22
# 5       2
# Name: NumTopCrew, dtype: int64

# %%
corr = pearsonr(data2['NumTopCrew'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between NumTopCrew and Gross: %.3f' % corr)
data2.plot.scatter(x='NumTopCrew', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between NumTopCrew and Gross: 0.630
# <AxesSubplot:xlabel='NumTopCrew', ylabel='Gross_worldwide'>

# %%
final['NumTopCrew'] = data2['NumTopCrew']

# %% [markdown]
# Consider film have crew in top 50

# %%
releases4crew.sort_values(by='Mean', ascending=False, inplace=True)
top50Crew = list(releases4crew['Crew'][0:50])


def getHasTopCrew(crews):
    for crew in crews:
        if crew in top50Crew:
            return 1
    return 0


data2 = data.copy()
data2['HasTopCrew'] = data2['Crew'].apply(getHasTopCrew)
data2['HasTopCrew'].value_counts()
# Out:
# 0    8467
# 1     272
# Name: HasTopCrew, dtype: int64

# %%
corr = pearsonr(data2['HasTopCrew'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between HasTopCrew and Gross: %.3f' % corr)
data2.plot.scatter(x='HasTopCrew', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between HasTopCrew and Gross: 0.550
# <AxesSubplot:xlabel='HasTopCrew', ylabel='Gross_worldwide'>

# %%
final['HasTopCrew'] = data2['HasTopCrew']

# %% [markdown]
# ## Studio Analysis

# %% [markdown]
# Hypothesis: Is gross depends on number of Studios participate in?

# %%
data2 = data.copy()
data2['NumStudios'] = data2['Studios'].apply(lambda x: len(x))
data2['NumStudios'].value_counts()
# Out:
# 3    5294
# 2    2064
# 1    1311
# 0      37
# 4      29
# 5       4
# Name: NumStudios, dtype: int64

# %%
data2['NumStudios'].value_counts().reset_index().sort_values(by='index', ascending=True).plot.bar(x='index',
                                                                                                  y='NumStudios')
corr = pearsonr(data2['NumStudios'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between NumStudios and Gross: %.3f' % corr)
data2.plot.scatter(x='NumStudios', y='Gross_worldwide', color='purple')
# Out:
# Pearsons correlation between NumStudios and Gross: 0.133
# <AxesSubplot:xlabel='NumStudios', ylabel='Gross_worldwide'>

# %%
final['NumStudios'] = data2['NumStudios']

# %% [markdown]
# Correlation **0.112**: Not very relevant
#
# Movies with Number of Studios Of 4 or 5 may be outlier. We will try to drop it.

# %%
data3 = data2.drop(list(data[data2['NumStudios'] == 4].index), axis=0)
data3 = data3.drop(list(data[data2['NumStudios'] == 5].index), axis=0)

# %%
data3['NumStudios'].value_counts().reset_index().sort_values(by='index', ascending=True).plot.bar(x='index',
                                                                                                  y='NumStudios')
corr = pearsonr(data3['NumStudios'], data3['Gross_worldwide'])[0]
print('Pearsons correlation between NumStudios and Gross: %.3f' % corr)
data3.plot.scatter(x='NumStudios', y='Gross_worldwide', color='purple')
# Out:
# Pearsons correlation between NumStudios and Gross: 0.132
# <AxesSubplot:xlabel='NumStudios', ylabel='Gross_worldwide'>

# %% [markdown]
# Correlation stay the same so we don't need to delete them

# %% [markdown]
# Studio and Gross of the movies they work for
# * Have not devide gross to each Studio if they coop together

# %%
studio = parseWithMoneyAndCount(data, 'Studios')
fig = plt.figure(figsize=(8, 4))
# plt.subplot(2,1,1)
data2 = studio.sort_values(by='Count', ascending=False)[0:15]
plt.bar(data=data2, x='Studios', height='Count', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.ylabel("Number Of Movies", fontsize=10)
plt.title("Studio and Number Of Movies they work for", fontsize=15)
plt.show()

fig = plt.figure(figsize=(8, 4))
# plt.subplot(2,1,1)
data2 = studio.sort_values(by='Total', ascending=False)[0:15]
plt.bar(data=data2, x='Studios', height='Total', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.ylabel("Total Gross", fontsize=10)
plt.title("Studio and Total Gross of Movies they work for", fontsize=15)
plt.show()
# plt.subplot(2,1,2)
fig = plt.figure(figsize=(8, 4))
data3 = studio.sort_values(by='Mean', ascending=False)[0:15]
plt.bar(data=data3, x='Studios', height='Mean', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Studio and Average Gross per movie they work for", fontsize=15)
plt.xlabel("Studio", fontsize=10)
plt.ylabel("Average Gross", fontsize=10)
plt.show()

fig = plt.figure(figsize=(8, 4))
data3 = studio.sort_values(by='Median', ascending=False)[0:15]
plt.bar(data=data3, x='Studios', height='Median', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Studio and Average Gross per movie they work for", fontsize=15)
plt.xlabel("Studio", fontsize=10)
plt.ylabel("Average Gross", fontsize=10)
plt.show()

# %%
studio.sort_values(by='Mean', ascending=False)
# Out:
#                                Studios       Total  Count          Mean  \
# 3418         Jason Roberts Productions  2052415039      1  2.052415e+09
# 5774                    South Pictures  2052415039      1  2.052415e+09
# 6570  Vita-Ray Dutch Productions (III)  1155046416      1  1.155046e+09
# 5300                          Rideback  1054304000      1  1.054304e+09
# 5544           Second Mate Productions  2027870956      2  1.013935e+09
# ...                                ...         ...    ...           ...
# 4689              Otto Preminger Films         194      1  1.940000e+02
# 6426                        Ultra Film         190      1  1.900000e+02
# 3423                         Jaz Films          95      1  9.500000e+01
# 2122          Elmer Gantry Productions          64      1  6.400000e+01
# 491                 Armada Productions          63      1  6.300000e+01
#
#             Median
# 3418  2.052415e+09
# 5774  2.052415e+09
# 6570  1.155046e+09
# 5300  1.054304e+09
# 5544  1.013935e+09
# ...            ...
# 4689  1.940000e+02
# 6426  1.900000e+02
# 3423  9.500000e+01
# 2122  6.400000e+01
# 491   6.300000e+01
#
# [6831 rows x 5 columns]

# %% [markdown]
# This average gross plot for studio is not reliable to decide which Studio is big or not since there are some Studios which participate only in one Movie
#
# We can define big studios by 4 ways:
#
# - Number of movies releases
# - Mean gross of movies they release
# - Median gross of movies they release
# - Total gross of movies they release

# %% [markdown]
# Now we will exclude the Studio with releases lower than 5

# %%
studios10Larger = studio[studio['Count'] > 5]
studios10Larger = studios10Larger.sort_values(by='Mean', ascending=False)
fig = plt.figure(figsize=(8, 4))
plt.bar(data=studios10Larger[0:25], x='Studios', height='Mean', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Studio and Average Gross per movie they work for", fontsize=15)
plt.xlabel("Studio", fontsize=10)
plt.ylabel("Average Gross", fontsize=10)
plt.show()
studios10Larger
# Out:
#                                   Studios        Total  Count          Mean  \
# 3814             Lightstorm Entertainment   8854415938      9  9.838240e+08
# 4092                       Marvel Studios  29525014615     33  8.946974e+08
# 3203           Illumination Entertainment   8076229648     12  6.730191e+08
# 4942              Pixar Animation Studios  15109966555     24  6.295819e+08
# 5983                              Syncopy   3777121192      6  6.295202e+08
# ...                                   ...          ...    ...           ...
# 4421  National Film Board of Canada (NFB)     13151342      6  2.191890e+06
# 6793                 Zenith Entertainment     17321794      8  2.165224e+06
# 2363              Film Four International      9545236      6  1.590873e+06
# 3660                       La Sept Cinéma     10915352      8  1.364419e+06
# 1584                    Concorde Pictures      8463581      7  1.209083e+06
#
#            Median
# 3814  404980543.0
# 4092  773350147.0
# 3203  588748184.5
# 4942  569780067.0
# 5983  597530912.5
# ...           ...
# 4421    1758702.0
# 6793    1708545.5
# 2363    1690371.5
# 3660    1229040.0
# 1584    1242995.0
#
# [586 rows x 5 columns]

# %% [markdown]
# The top studios bar chat now looks more familiar.
#
# Move on to rank the Studios.

# %%
studios10Larger.sort_values(by='Mean', ascending=True, inplace=True)
studioRank = dict()
for i, row in enumerate(studios10Larger['Studios']):
    studioRank[row] = i + 1
studioRank
# Out:
# {'Concorde Pictures': 1,
#  'La Sept Cinéma': 2,
#  'Film Four International': 3,
#  'Zenith Entertainment': 4,
#  'National Film Board of Canada (NFB)': 5,
#  'A&E IndieFilms': 6,
#  'British Screen Productions': 7,
#  'RAI Radiotelevisione Italiana': 8,
#  'American Playhouse': 9,
#  'CG Cinéma': 10,
#  'Lorimar Motion Pictures': 11,
#  'Diamond Docs': 12,
#  'Arte France Cinéma': 13,
#  'MK2 Productions': 14,
#  'Arts Council of England': 15,
#  'Road Movies Filmproduktion': 16,
#  'CBS Theatrical Films': 17,
#  'Alliance Communications Corporation': 18,
#  'Live Entertainment': 19,
#  'October Films': 20,
#  'Triumph Films': 21,
#  'The Rank Organisation': 22,
#  'Trimark Pictures': 23,
#  'Alliance Entertainment': 24,
#  'Fine Line Features': 25,
#  'Téléfilm Canada': 26,
#  'Cineplex Odeon Films': 27,
#  'Rhombus Media': 28,
#  'Canadian Film Development Corporation (CFDC)': 29,
#  'Les Films Alain Sarde': 30,
#  'CiBy 2000': 31,
#  'Vision PDG': 32,
#  'Danmarks Radio (DR)': 33,
#  'Lorimar Productions': 34,
#  'Merchant Ivory Productions': 35,
#  'Balcor Film Investors': 36,
#  'Renaissance Films': 37,
#  'New World Pictures': 38,
#  'Celluloid Dreams': 39,
#  'Big Indie Pictures': 40,
#  'The Samuel Goldwyn Company': 41,
#  'Weintraub Entertainment Group': 42,
#  'Silver Screen Partners': 43,
#  'HBO Pictures': 44,
#  'Senator Film Produktion': 45,
#  'Atlantic Entertainment Group': 46,
#  'Golan-Globus Productions': 47,
#  'Alliance Atlantis Communications': 48,
#  'De Laurentiis Entertainment Group (DEG)': 49,
#  'DD Productions': 50,
#  'Killer Films': 51,
#  'Avenue Pictures': 52,
#  'Delphi III Productions': 53,
#  'Savoy Pictures': 54,
#  'Island Pictures': 55,
#  'Cannon Films': 56,
#  'Worldview Entertainment': 57,
#  'Faliro House Productions': 58,
#  'Price Entertainment': 59,
#  'Sony Pictures Classics': 60,
#  'The Mirisch Corporation': 61,
#  'Hart Sharp Entertainment': 62,
#  'The Cannon Group': 63,
#  'A&M Films': 64,
#  'France 3 Cinéma': 65,
#  'Destination Films': 66,
#  'Kings Road Entertainment': 67,
#  'Muse Productions': 68,
#  'Serendipity Point Films': 69,
#  'Broad Green Pictures': 70,
#  'Recorded Picture Company (RPC)': 71,
#  'Alive Films': 72,
#  'Embassy Pictures': 73,
#  'Distant Horizon': 74,
#  'Cinémaginaire Inc.': 75,
#  'Capitol Films': 76,
#  'Sweetland Films': 77,
#  'ML Delphi Premier Productions': 78,
#  'FilmFour': 79,
#  'Good Machine': 80,
#  'Viacom18 Motion Pictures': 81,
#  'Likely Story': 82,
#  'Gladden Entertainment': 83,
#  'Palace Pictures': 84,
#  'Australian Film Finance Corporation (AFFC)': 85,
#  'Bavaria Film': 86,
#  'Amazon Studios': 87,
#  'Island World': 88,
#  'Excel Entertainment': 89,
#  'Isle of Man Film': 90,
#  'Artisan Entertainment': 91,
#  'Rai Cinema': 92,
#  'John Wells Productions': 93,
#  'Producers Sales Organization (PSO)': 94,
#  'Eros Worldwide': 95,
#  'Element Films': 96,
#  'Detour Filmproduction': 97,
#  'Empire Pictures': 98,
#  'Epic Productions': 99,
#  'Capital Arts Entertainment': 100,
#  'Nelvana': 101,
#  'TAFT Entertainment Pictures': 102,
#  'British Film Institute (BFI)': 103,
#  'British Broadcasting Corporation (BBC)': 104,
#  'The Bubble Factory': 105,
#  'IFC Productions': 106,
#  'Pandora Filmproduktion': 107,
#  "Centre national du cinéma et de l'image animée (CNC)": 108,
#  'MDP Worldwide': 109,
#  'Redchillies.VFX': 110,
#  'Fandango': 111,
#  'ApolloMedia Distribution': 112,
#  'HanWay Films': 113,
#  'Automatik Entertainment': 114,
#  'Goldcrest Films International': 115,
#  'Haut et Court': 116,
#  'Cinerenta Medienbeteiligungs KG': 117,
#  'Bord Scannán na hÉireann / The Irish Film Board': 118,
#  'Renn Productions': 119,
#  'Why Not Productions': 120,
#  'Propaganda Films': 121,
#  'Warner Independent Pictures (WIP)': 122,
#  'Riverstone Pictures': 123,
#  'GreeneStreet Films': 124,
#  'Channel Four Films': 125,
#  'Fox STAR Studios': 126,
#  'Dharma Productions': 127,
#  'Red Chillies Entertainment': 128,
#  'Kingsgate Films': 129,
#  'France 2 Cinéma': 130,
#  'Enigma Productions': 131,
#  'Nadiadwala Grandson Entertainment': 132,
#  'Zentropa Entertainments': 133,
#  'Spelling Films': 134,
#  'Bac Films': 135,
#  'Jack Rollins & Charles H. Joffe Productions': 136,
#  'Marty Katz Productions': 137,
#  'Lorimar Film Entertainment': 138,
#  'Film i Väst': 139,
#  'Sean S. Cunningham Films': 140,
#  'Incorporated Television Company (ITC)': 141,
#  'HandMade Films': 142,
#  'Hemdale': 143,
#  'Warner Bros. Animation': 144,
#  'ABC Motion Pictures': 145,
#  'Provident Films': 146,
#  'Overture Films': 147,
#  '2929 Productions': 148,
#  'Groundswell Productions': 149,
#  'RKO Pictures': 150,
#  'Seven Arts Productions': 151,
#  'LD Entertainment': 152,
#  'Brooksfilms': 153,
#  'Vestron Pictures': 154,
#  'Big Beach Films': 155,
#  'Broadway Pictures': 156,
#  'ARTE': 157,
#  'Fox Atomic': 158,
#  'Delphi V Productions': 159,
#  'This Is That Productions': 160,
#  'Depth of Field': 161,
#  'Largo Entertainment': 162,
#  'Industry Entertainment': 163,
#  'Medusa Film': 164,
#  'Hawn / Sylbert Movie Company': 165,
#  'View Askew Productions': 166,
#  "Hell's Kitchen Films": 167,
#  'First Artists': 168,
#  'Canal+ España': 169,
#  'Rysher Entertainment': 170,
#  'Orion Pictures': 171,
#  '40 Acres & A Mule Filmworks': 172,
#  'JVC Entertainment Networks': 173,
#  'The': 174,
#  'Jackson/McHenry Company': 175,
#  'H2L Media Group': 176,
#  'Franchise Pictures': 177,
#  'Pressman Film': 178,
#  'Walt Disney Productions': 179,
#  'Turner Pictures (I)': 180,
#  'IAC Films': 181,
#  'El Deseo': 182,
#  'Yash Raj Films': 183,
#  'Sidney Kimmel Entertainment': 184,
#  'Delphi II Productions': 185,
#  'IM Global': 186,
#  'Touchstone Films': 187,
#  'Brightlight Pictures': 188,
#  'Delphi IV Productions': 189,
#  'Capella International': 190,
#  'UTV Motion Pictures': 191,
#  'Smart Egg Pictures': 192,
#  'RadicalMedia': 193,
#  'Art Linson Productions': 194,
#  'BBC Films': 195,
#  'A24': 196,
#  'Westdeutscher Rundfunk (WDR)': 197,
#  'New Deal Productions': 198,
#  'The Geffen Company': 199,
#  'Amercent Films': 200,
#  'Nelson Entertainment': 201,
#  'Bob Yari Productions': 202,
#  'SLM Production Group': 203,
#  'Pathé Pictures International': 204,
#  'X-Filme Creative Pool': 205,
#  'Gaylord Films': 206,
#  'Touchwood Pacific Partners 1': 207,
#  'Bona Fide Productions': 208,
#  'Permut Presentations': 209,
#  'Brillstein-Grey Entertainment': 210,
#  'Silver Screen Partners II': 211,
#  'Pantelion Films': 212,
#  'The Malpaso Company': 213,
#  'Trilogy Entertainment Group': 214,
#  'Gaumont': 215,
#  'Turman-Foster Company': 216,
#  'Wild Bunch': 217,
#  'Sandollar Productions': 218,
#  'Film4': 219,
#  'Vinod Chopra Productions': 220,
#  'Ghoulardi Film Company': 221,
#  'Waypoint Entertainment': 222,
#  'Samuel Goldwyn Films': 223,
#  'Bold Films': 224,
#  'Rastar Pictures': 225,
#  'Gramercy Pictures (I)': 226,
#  'Morgan Creek Entertainment': 227,
#  'Zoetrope Studios': 228,
#  'FilmEngine': 229,
#  'The Ladd Company': 230,
#  'Madison Wells': 231,
#  'Intrepid Pictures': 232,
#  'Indian Paintbrush': 233,
#  'Imagenation Abu Dhabi FZ': 234,
#  'Affirm Films': 235,
#  'Dino De Laurentiis Company': 236,
#  'EMI Films': 237,
#  'National Lampoon': 238,
#  'American Zoetrope': 239,
#  'Robert Evans Company': 240,
#  'Cheyenne Enterprises': 241,
#  'Caravan Pictures': 242,
#  'Melvin Simon Productions': 243,
#  'Anonymous Content': 244,
#  'UK Film Council': 245,
#  'Disneynature': 246,
#  'Voltage Pictures': 247,
#  'IndieProd Company Productions': 248,
#  'Winkler Films': 249,
#  "Cinema '84": 250,
#  'Searchlight Pictures': 251,
#  'Les Productions Artistes Associés': 252,
#  'DNA Films': 253,
#  'Broadway Video': 254,
#  'Rogue Pictures': 255,
#  'Hyde Park Entertainment': 256,
#  'Lions Gate Films': 257,
#  'Ruby Films': 258,
#  'Bregman/Baer Productions': 259,
#  'Exclusive Media Group': 260,
#  'Clinica Estetico': 261,
#  'HBO Films': 262,
#  'Rastar Films': 263,
#  'Outlaw Productions (I)': 264,
#  'Mad Chance': 265,
#  'Canal+': 266,
#  'Gran Via Productions': 267,
#  'FilmNation Entertainment': 268,
#  'Section Eight': 269,
#  'Motion Picture Corporation of America (MPCA)': 270,
#  'Cecchi Gori Group Tiger Cinematografica': 271,
#  'Hollywood Pictures': 272,
#  'Black Bear Pictures': 273,
#  'Mr. Mudd': 274,
#  'Geffen Pictures': 275,
#  'Epsilon Motion Pictures': 276,
#  'Wildwood Enterprises': 277,
#  'State Street Pictures': 278,
#  'Odyssey Entertainment': 279,
#  'Endgame Entertainment': 280,
#  'Perdido Productions': 281,
#  'Mandalay Entertainment': 282,
#  'Stage 6 Films': 283,
#  'Davis-Films': 284,
#  'Interscope Communications': 285,
#  'Miramax': 286,
#  'Open Road Films (II)': 287,
#  'Cinema Group Ventures': 288,
#  'DiNovi Pictures': 289,
#  'American Empirical Pictures': 290,
#  'Spring Creek Productions': 291,
#  'Alcor Films': 292,
#  'Tyler Perry Studios': 293,
#  'Polygram Filmed Entertainment': 294,
#  'Gravier Productions': 295,
#  'Participant': 296,
#  'Lakeshore Entertainment': 297,
#  'Beacon Communications': 298,
#  'Castle Rock Entertainment': 299,
#  'MTV Films': 300,
#  'Barwood Films': 301,
#  'Gran Via': 302,
#  'Laurence Mark Productions': 303,
#  'CBS Films': 304,
#  'Dark Castle Entertainment': 305,
#  'Toei Company': 306,
#  'The Tyler Perry Company': 307,
#  'Bel Air Entertainment': 308,
#  'Paramount Vantage': 309,
#  'Aamir Khan Productions': 310,
#  'TriStar Pictures': 311,
#  'BRON Studios': 312,
#  'David Foster Productions': 313,
#  'The Montecito Picture Company': 314,
#  'Misher Films': 315,
#  'Sprockets Music': 316,
#  'Tapestry Films': 317,
#  'Rainforest Films': 318,
#  'Lawrence Bender Productions': 319,
#  'Baltimore Pictures': 320,
#  'Screen Gems': 321,
#  'Beacon Pictures': 322,
#  'Phoenix Pictures': 323,
#  'Bazelevs Production': 324,
#  'Saturn Films': 325,
#  'St. Petersburg Clearwater Film Commission': 326,
#  'United Artists': 327,
#  'Hanna-Barbera Productions': 328,
#  'Major Studio Partners': 329,
#  'Intermedia Films': 330,
#  'Ixtlan': 331,
#  'Focus Features': 332,
#  'Estudios Churubusco Azteca S.A.': 333,
#  'Robert Simonds Productions': 334,
#  'Dimension Films': 335,
#  'River Road Entertainment': 336,
#  'Pariah': 337,
#  'Cube Vision': 338,
#  'PolyGram Filmed Entertainment': 339,
#  'Jersey Films': 340,
#  'Emmett/Furla/Oasis Films (EFO Films)': 341,
#  'Disney Television Animation': 342,
#  'Pathé': 343,
#  'Entertainment One': 344,
#  'Carolco Pictures': 345,
#  'Star Partners II Ltd.': 346,
#  'Lawrence Gordon Productions': 347,
#  'Zucker Brothers Productions': 348,
#  '3 Arts Entertainment': 349,
#  'Tollin/Robbins Productions': 350,
#  'Face Productions': 351,
#  'Playtone': 352,
#  'Golden Harvest Company': 353,
#  'Imagine Films Entertainment': 354,
#  'Newmarket Capital Group': 355,
#  'Conundrum Entertainment': 356,
#  'Shangri-La Entertainment': 357,
#  'Cinergi Pictures Entertainment': 358,
#  'Silver Screen Partners III': 359,
#  'Double Feature Films': 360,
#  'Amen Ra Films': 361,
#  'Home Box Office (HBO)': 362,
#  'Mandate Pictures': 363,
#  'The Guber-Peters Company': 364,
#  'FilmDistrict': 365,
#  'Icon Entertainment International': 366,
#  'Strike Entertainment': 367,
#  'Mirage Enterprises': 368,
#  'Tribeca Productions': 369,
#  'TF1 Films Production': 370,
#  'Mandalay Pictures': 371,
#  'Plan B Entertainment': 372,
#  'Mayhem Pictures': 373,
#  'Touchstone Pictures': 374,
#  'FilmColony': 375,
#  'The Weinstein Company': 376,
#  'Silver Screen Partners IV': 377,
#  'Alcon Entertainment': 378,
#  'Allied Filmmakers': 379,
#  'STX Entertainment': 380,
#  'CJ Entertainment': 381,
#  'Will Packer Productions': 382,
#  'Annapurna Pictures': 383,
#  'StudioCanal': 384,
#  'Delphi Films': 385,
#  'DENTSU Music And Entertainment': 386,
#  'Dune Entertainment III': 387,
#  'Gerber Pictures': 388,
#  'Warner Bros. Family Entertainment': 389,
#  'The Mark Gordon Company': 390,
#  'Dark Horse Entertainment': 391,
#  'Metro-Goldwyn-Mayer (MGM)': 392,
#  'Global Entertainment Productions GmbH & Company Medien KG': 393,
#  'Pacific Western': 394,
#  'Goldcrest Pictures': 395,
#  'Craven-Maddalena Films': 396,
#  'Avnet/Kerner Productions': 397,
#  'Working Title Films': 398,
#  'Millennium Films': 399,
#  'Malpaso Productions': 400,
#  'Constantin Film': 401,
#  'Revolution Studios': 402,
#  'China Film Co-Production Corporation': 403,
#  'Contrafilm': 404,
#  'Initial Entertainment Group (IEG)': 405,
#  'Brad Grey Pictures': 406,
#  'Cold Spring Pictures': 407,
#  'Karz Entertainment': 408,
#  'Icon Productions': 409,
#  'Mutual Film Company': 410,
#  'Anton': 411,
#  'Gold Circle Films': 412,
#  'Good Universe': 413,
#  'Avery Pix': 414,
#  'EuropaCorp': 415,
#  'Chartoff-Winkler Productions': 416,
#  'Scott Rudin Productions': 417,
#  'Laika Entertainment': 418,
#  'Ghost House Pictures': 419,
#  'Hughes Entertainment': 420,
#  'Broken Road Productions': 421,
#  'Blumhouse Productions': 422,
#  'Appian Way': 423,
#  'Escape Artists': 424,
#  'Point Grey Pictures': 425,
#  'Tall Trees Productions': 426,
#  'Majestic Films International': 427,
#  'Disneytoon Studios': 428,
#  'Huayi Brothers Media': 429,
#  'BenderSpink': 430,
#  'Bluegrass Films': 431,
#  'Red Hour Films': 432,
#  'Smokehouse Pictures': 433,
#  'Cross Creek Pictures': 434,
#  'Mace Neufeld Productions': 435,
#  'Lionsgate': 436,
#  'Radar Pictures': 437,
#  'Black Label Media': 438,
#  'Davis Entertainment': 439,
#  'New Line Cinema': 440,
#  'Apatow Productions': 441,
#  'New Regency Productions': 442,
#  'A Band Apart': 443,
#  'Gordon Company': 444,
#  'Marc Platt Productions': 445,
#  'Konrad Pictures': 446,
#  'Alphaville Films': 447,
#  'Canadian Film or Video Production Tax Credit (CPTC)': 448,
#  'Twisted Pictures': 449,
#  'QED International': 450,
#  'De Line Pictures': 451,
#  'Silver Pictures': 452,
#  'Imagine Entertainment': 453,
#  'Offspring Entertainment': 454,
#  'Northern Lights Entertainment': 455,
#  'Kennedy Miller Productions': 456,
#  'Fox 2000 Pictures': 457,
#  'Scott Free Productions': 458,
#  'Protozoa Pictures': 459,
#  'Donner/Shuler-Donner Productions': 460,
#  'Gary Sanchez Productions': 461,
#  'Reliance Entertainment': 462,
#  'Flower Films (II)': 463,
#  '21 Laps Entertainment': 464,
#  'Thunder Road Pictures': 465,
#  'TIK Films': 466,
#  'Spyglass Entertainment': 467,
#  'Studio Ghibli': 468,
#  'Nickelodeon Movies': 469,
#  'Happy Madison Productions': 470,
#  'The Zanuck Company': 471,
#  'Paramount Pictures': 472,
#  'Forward Pass': 473,
#  'Mosaic': 474,
#  'Impact Pictures': 475,
#  'Gracie Films': 476,
#  'Columbia Pictures': 477,
#  'Universal Pictures': 478,
#  'Summit Entertainment': 479,
#  'Walden Media': 480,
#  'Relativity Media': 481,
#  'Twentieth Century Fox': 482,
#  'Platinum Dunes': 483,
#  'NPV Entertainment': 484,
#  'Eddie Murphy Productions': 485,
#  'Red Wagon Entertainment': 486,
#  'Nippon Television Network (NTV)': 487,
#  'Ingenious Film Partners': 488,
#  'Jerry Weintraub Productions': 489,
#  'Marv Films': 490,
#  'Red Granite Pictures': 491,
#  'Warner Bros.': 492,
#  'Brandywine Productions': 493,
#  'Roger Birnbaum Productions': 494,
#  'Troublemaker Studios': 495,
#  'Aardman Animations': 496,
#  'Gunn Films': 497,
#  'Solana Films': 498,
#  'Virtual Studios': 499,
#  'Tig Productions': 500,
#  'Mandeville Films': 501,
#  'RatPac Entertainment': 502,
#  'Sony Pictures Entertainment (SPE)': 503,
#  'Ingenious Media': 504,
#  'Valhalla Motion Pictures': 505,
#  'Dreamworks Pictures': 506,
#  'Tim Burton Productions': 507,
#  'Zanuck/Brown Productions': 508,
#  'Zide-Perry Productions': 509,
#  "Donners' Company": 510,
#  'Team Todd': 511,
#  'ImageMovers': 512,
#  'Kopelson Entertainment': 513,
#  'The Bedford Falls Company': 514,
#  'Parkes/MacDonald Image Nation': 515,
#  'M6 Films': 516,
#  'LStar Capital': 517,
#  'China Film Group Corporation (CFGC)': 518,
#  'Perfect World Pictures': 519,
#  'Eon Productions': 520,
#  'Overbrook Entertainment': 521,
#  'Original Film': 522,
#  'Vertigo Entertainment': 523,
#  'Prime Focus': 524,
#  'Digital Image Associates': 525,
#  'Village Roadshow Pictures': 526,
#  'Di Bonaventura Pictures': 527,
#  'Michael De Luca Productions': 528,
#  'GK Films': 529,
#  'DMG Entertainment': 530,
#  'Cruise/Wagner Productions': 531,
#  'Don Simpson/Jerry Bruckheimer Films': 532,
#  'RatPac-Dune Entertainment': 533,
#  'Grive Productions': 534,
#  'Atomic Monster': 535,
#  'Chernin Entertainment': 536,
#  'The Kennedy/Marshall Company': 537,
#  'Media Rights Capital (MRC)': 538,
#  'Bona Film Group': 539,
#  'Dentsu': 540,
#  'Blinding Edge Pictures': 541,
#  'Amblin Entertainment': 542,
#  'Temple Hill Entertainment': 543,
#  'TSG Entertainment': 544,
#  'Dune Entertainment': 545,
#  'Sony Pictures Animation': 546,
#  'Atlas Entertainment': 547,
#  'The Safran Company': 548,
#  'FortyFour Studios': 549,
#  'Walt Disney Animation Studios': 550,
#  'Green Hat Films': 551,
#  'Studio Babelsberg': 552,
#  'DreamWorks': 553,
#  '1492 Pictures': 554,
#  'Maverick Films': 555,
#  'Sunswept Entertainment': 556,
#  'Color Force': 557,
#  'Alibaba Pictures': 558,
#  'Walt Disney Pictures': 559,
#  'Animal Logic': 560,
#  'Twentieth Century Fox Animation': 561,
#  'Legendary Entertainment': 562,
#  'Marvel Enterprises': 563,
#  'Jerry Bruckheimer Films': 564,
#  'Centropolis Entertainment': 565,
#  'Skydance Media': 566,
#  'Roth Films': 567,
#  'The Saul Zaentz Company': 568,
#  'DreamWorks Animation': 569,
#  'DC Entertainment': 570,
#  'Bad Robot': 571,
#  'Blue Sky Studios': 572,
#  'Hasbro': 573,
#  '20th Century Studios': 574,
#  'Danjaq': 575,
#  'Lucasfilm': 576,
#  'Pacific Data Images (PDI)': 577,
#  'Marvel Entertainment': 578,
#  'WingNut Films': 579,
#  'Laura Ziskin Productions': 580,
#  'Heyday Films': 581,
#  'Syncopy': 582,
#  'Pixar Animation Studios': 583,
#  'Illumination Entertainment': 584,
#  'Marvel Studios': 585,
#  'Lightstorm Entertainment': 586}

# %% [markdown]
# Apply by get the max rank in the list of Studios for each movie
#
# The studio not appear in the list will be randomly choose rank between **0** and **200**

# %%
import random


def getStudioRank(studios):
    max = 0
    for studio in studios:
        if studio not in studioRank.keys():
            continue
        if studioRank[studio] > max:
            max = studioRank[studio]
    if max != 0:
        return max
    return random.randint(1, 200)


data2 = data.copy()
data2['StudioRank'] = data2['Studios'].apply(getStudioRank)
corr = pearsonr(data2['StudioRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between StudioRank and Gross: %.3f' % corr)
data2.plot.scatter(x='StudioRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between StudioRank and Gross: 0.391
# <AxesSubplot:xlabel='StudioRank', ylabel='Gross_worldwide'>

# %% [markdown]
# Apply by get the total rank in the list of Studios for each movie
#
# The studio not appear in the list will be randomly choose rank between **0** and **200**

# %%
import random


def getStudioRank(studios):
    total = 0
    for studio in studios:
        if studio not in studioRank.keys():
            total += random.randint(1, 200)
            continue
        total += studioRank[studio]
    return total


data2 = data.copy()
data2['StudioRank'] = data2['Studios'].apply(getStudioRank)
corr = pearsonr(data2['StudioRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between StudioRank and Gross: %.3f' % corr)
data2.plot.scatter(x='StudioRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between StudioRank and Gross: 0.469
# <AxesSubplot:xlabel='StudioRank', ylabel='Gross_worldwide'>

# %%
final['StudioRank'] = data2['StudioRank']

# %% [markdown]
# Apply by get the mean rank in the list of Studios for each movie
#
# The studio not appear in the list will be randomly choose rank between **0** and **200**

# %%
import random


def getStudioRank(studios):
    total = 0
    length = len(studios)
    if length == 0:
        length = 1
    for studio in studios:
        if studio not in studioRank.keys():
            total += random.randint(0, 200)
            continue
        total += studioRank[studio]
    return total / length


data2 = data.copy()
data2['StudioRank'] = data2['Studios'].apply(getStudioRank)
corr = pearsonr(data2['StudioRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between StudioRank and Gross: %.3f' % corr)
data2.plot.scatter(x='StudioRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between StudioRank and Gross: 0.432
# <AxesSubplot:xlabel='StudioRank', ylabel='Gross_worldwide'>

# %% [markdown]
# Decide to choose **total rank**

# %% [markdown]
# Now we will extract more feature That is:
# - Number of top studios(Studio that in the top **100**)
# - Boolean (0,1) Have studio in high top (In top **30**)

# %% [markdown]
# NumTopStudios

# %%
studios10Larger.sort_values(by='Mean', ascending=False, inplace=True)
top100Studios = list(studios10Larger['Studios'][0:100])


def getNumTopStudios(studios):
    total = 0
    for studio in studios:
        if studio in top100Studios:
            total += 1
    return total


data2 = data.copy()
data2['NumTopStudios'] = data2['Studios'].apply(getNumTopStudios)
data2['NumTopStudios'].value_counts()
# Out:
# 0    6976
# 1    1247
# 2     452
# 3      64
# Name: NumTopStudios, dtype: int64

# %%
corr = pearsonr(data2['NumTopStudios'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between NumTopStudios and Gross: %.3f' % corr)
data2.plot.scatter(x='NumTopStudios', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between NumTopStudios and Gross: 0.529
# <AxesSubplot:xlabel='NumTopStudios', ylabel='Gross_worldwide'>

# %%
final['NumTopStudios'] = data2['NumTopStudios']

# %% [markdown]
# HasTopStudio

# %%
studios10Larger.sort_values(by='Mean', ascending=False, inplace=True)
top100Studios = list(studios10Larger['Studios'][0:30])


def getHasTopStudio(studios):
    for studio in studios:
        if studio in top100Studios:
            return 1
    return 0


data2 = data.copy()
data2['HasTopStudio'] = data2['Studios'].apply(getHasTopStudio)
data2['HasTopStudio'].value_counts()
corr = pearsonr(data2['HasTopStudio'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between HasTopStudio and Gross: %.3f' % corr)
data2.plot.scatter(x='HasTopStudio', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between HasTopStudio and Gross: 0.505
# <AxesSubplot:xlabel='HasTopStudio', ylabel='Gross_worldwide'>

# %%
final['HasTopStudio'] = data2['HasTopStudio']

# %% [markdown]
# ## Production Countries Analysis

# %% [markdown]
# Hypothesis: Is gross depend on number of Production Companies in each movie?

# %%
data2 = data.copy()
data2['Countries'] = data2['Countries'].apply(lambda x: len(x))
data2['Countries'].value_counts()
# Out:
# 1     5847
# 2     1825
# 3      649
# 4      257
# 5      103
# 6       34
# 7       11
# 0        5
# 8        4
# 9        2
# 17       1
# 11       1
# Name: Countries, dtype: int64

# %%
corr = pearsonr(data2['Countries'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between Countries and Gross: %.3f' % corr)
data2.plot.scatter(x='Countries', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between Countries and Gross: 0.049
# <AxesSubplot:xlabel='Countries', ylabel='Gross_worldwide'>

# %% [markdown]
# Very low correlation of **0.079**

# %% [markdown]
# Gross of each countries and Total Gross
# * Have not devide gross to each Country if they coop together

# %%
country = parseWithMoneyAndCount(data, 'Countries')
# country=country[country['Count']>20]
fig = plt.figure(figsize=(8, 4))
# plt.subplot(2,1,1)
data2 = country.sort_values(by='Count', ascending=False)[0:20]
plt.bar(data=data2, x='Countries', height='Count', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.ylabel("Releases", fontsize=20)
plt.title("Movie Releases By Country", fontsize=20)
fig = plt.figure(figsize=(8, 4))
# plt.subplot(2,1,2)
data2 = country.sort_values(by='Total', ascending=False)[0:20]
plt.bar(data=data2, x='Countries', height='Total', color="salmon")
plt.ylabel("Total Gross", fontsize=20)
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Countries", fontsize=20)
plt.title("Total Gross By Country", fontsize=20)

fig = plt.figure(figsize=(8, 4))
# plt.subplot(2,1,1)
data2 = country.sort_values(by='Mean', ascending=False)[0:20]
plt.bar(data=data2, x='Countries', height='Mean', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.ylabel("Average Gross", fontsize=20)
plt.title("Average Gross By Country", fontsize=20)
plt.show()
## This use for QUESTION 8
list_country = list(country['Countries'])

# %% [markdown]
# This rank of average gross is not relevant since there are some countries with only least release count

# %%
country.sort_values(by='Mean', ascending=False)
# Out:
#          Countries       Total  Count          Mean       Median
# 5          Bahamas   616505162      1  6.165052e+08  616505162.0
# 56           Malta  4014145147     10  4.014145e+08  425101966.5
# 65     New Zealand  9439949395     42  2.247607e+08   70111024.5
# 95          Turkey  1562661007      7  2.232373e+08   15535312.0
# 85        Slovenia   424524437      2  2.122622e+08  212262218.5
# ..             ...         ...    ...           ...          ...
# 88    Soviet Union     3574341      4  8.935852e+05     677945.0
# 30         Georgia      686704      1  6.867040e+05     686704.0
# 52         Liberia      555533      1  5.555330e+05     555533.0
# 34           Haiti      352296      1  3.522960e+05     352296.0
# 22  Czechoslovakia       34198      1  3.419800e+04      34198.0
#
# [107 rows x 5 columns]

# %% [markdown]
# We can see that almost movies are release in United States.
#
# We will test that: Is movies release in United States will have higher gross compare to other films?

# %%
data2 = data.copy()
data2['isUnitedStates'] = data2['Countries'].apply(lambda x: 1 if "United States" in x else 0)
corr = pearsonr(data2['isUnitedStates'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between isUnitedStates and Gross: %.3f' % corr)
data2.plot.scatter(x='isUnitedStates', y='Gross_worldwide', color='brown')
# Out:
# Pearsons correlation between isUnitedStates and Gross: 0.124
# <AxesSubplot:xlabel='isUnitedStates', ylabel='Gross_worldwide'>

# %%
final['isUnitedStates'] = data2['isUnitedStates']

# %% [markdown]
# Seems low correlation

# %% [markdown]
# Now we will exclude countries that have number of releases less than 100

# %%
country.sort_values(by='Mean', ascending=False)
release100Countries = country[country['Count'] >= 100]
release100Countries = release100Countries.sort_values(by='Mean', ascending=False)
release100Countries.plot.bar(x='Countries', y='Mean', color='green')
# Out:
# <AxesSubplot:xlabel='Countries'>

# %% [markdown]
# We will choose these list of Countries to extract a rank feature

# %%
release100Countries = release100Countries.sort_values(by='Mean', ascending=True).reset_index(drop=True)
countryRank = dict()
for i, row in enumerate(release100Countries['Countries']):
    countryRank[row] = i + 1  ## Plus 1 in order to release the 0 position for another film
countryRank
# Out:
# {'India': 1,
#  'Italy': 2,
#  'France': 3,
#  'Mexico': 4,
#  'Spain': 5,
#  'Germany': 6,
#  'Canada': 7,
#  'United Kingdom': 8,
#  'United States': 9,
#  'Hong Kong': 10,
#  'Australia': 11,
#  'Japan': 12,
#  'China': 13}

# %% [markdown]
# Get rank by the maximum

# %%
def getCountryRank(countries):
    max = 0
    for country in countries:
        if country not in countryRank.keys():
            continue
        if countryRank[country] > max:
            max = countryRank[country]
    if max == 0:
        max = random.randint(1, 10)
    return max


data2 = data.copy()
data2['CountryRank'] = data2['Countries'].apply(getCountryRank)
corr = pearsonr(data2['CountryRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between CountryRank and Gross: %.3f' % corr)
data2.plot.scatter(x='CountryRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between CountryRank and Gross: 0.141
# <AxesSubplot:xlabel='CountryRank', ylabel='Gross_worldwide'>

# %%
final['CountryRank'] = data2['CountryRank']

# %% [markdown]
# By total

# %%
def getCountryRank(countries):
    total = 0
    for country in countries:
        if country not in countryRank.keys():
            continue
        total += countryRank[country]
    return total


data2 = data.copy()
data2['CountryRank'] = data2['Countries'].apply(getCountryRank)
corr = pearsonr(data2['CountryRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between CountryRank and Gross: %.3f' % corr)
data2.plot.scatter(x='CountryRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between CountryRank and Gross: 0.134
# <AxesSubplot:xlabel='CountryRank', ylabel='Gross_worldwide'>

# %% [markdown]
# By in the list

# %%
def getCountryRank(countries):
    for country in countries:
        if country not in countryRank.keys():
            continue
        return 1
    return 0


data2 = data.copy()
data2['CountryRank'] = data2['Countries'].apply(getCountryRank)
corr = pearsonr(data2['CountryRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between CountryRank and Gross: %.3f' % corr)
data2.plot.scatter(x='CountryRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between CountryRank and Gross: 0.033
# <AxesSubplot:xlabel='CountryRank', ylabel='Gross_worldwide'>

# %% [markdown]
# ## Language analysis

# %% [markdown]
# How distribution release by Languague

# %%
language = parseWithMoneyAndCount(data, 'Languages')
data2 = language.sort_values(by='Total', ascending=False)[0:20]

fig = plt.figure(figsize=(8, 4))
plt.bar(data=data2, x='Languages', height='Count', color="salmon")
plt.ylabel("Releases", fontsize=20)
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Languages", fontsize=20)
plt.title("Release By Language", fontsize=20)
plt.show()

# %% [markdown]
# Nowadays, films almost have English. We will try to find that what is the film is spoken in English or another languages

# %%
data2 = data.copy()
data2['IsEnglish'] = data2['Languages'].apply(lambda x: 1 if 'English' in x else 0)
data2['IsEnglish'].value_counts()
# Out:
# 1    8162
# 0     577
# Name: IsEnglish, dtype: int64

# %%
corr = pearsonr(data2['IsEnglish'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between IsEnnglish and Gross: %.3f' % corr)
data2.plot.scatter(x='IsEnglish', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between IsEnnglish and Gross: 0.075
# <AxesSubplot:xlabel='IsEnglish', ylabel='Gross_worldwide'>

# %% [markdown]
# Correlation of 0.076

# %%
final['IsEnglish'] = data2['IsEnglish']

# %% [markdown]
# ## Keywords analysis

# %% [markdown]
# Hypothesis: Is gross depend on number of keywords?

# %%
data2 = data.copy()
data2['NumKeywords'] = data2['Keywords'].apply(lambda x: len(x))
data2['NumKeywords'].value_counts()
# Out:
# 5    8577
# 1      66
# 2      30
# 3      25
# 4      23
# 0      18
# Name: NumKeywords, dtype: int64

# %%
corr = pearsonr(data2['NumKeywords'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between NumKeywords and Gross: %.3f' % corr)
data2.plot.scatter(x='NumKeywords', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between NumKeywords and Gross: 0.041
# <AxesSubplot:xlabel='NumKeywords', ylabel='Gross_worldwide'>

# %% [markdown]
# Not relevant

# %% [markdown]
# How distribution of gross by Keywords

# %%
keyword = parseWithMoneyAndCount(data, 'Keywords')
fig = plt.figure(figsize=(8, 4))
data2 = keyword.sort_values(by='Count', ascending=False)[0:15]
plt.bar(data=data2, x='Keywords', height='Count', color="salmon")
plt.xticks(rotation=90, fontsize=10)
plt.title("Number of movie releases with certain kind of keywords", fontsize=15)
plt.ylabel("Count", fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
keyword.sort_values(by='Mean', ascending=False)[0:10]
# Out:
#                            Keywords       Total  Count          Mean  \
# 4888              forest protection  2923706026      1  2.923706e+09
# 2942                         cosmic  2799439100      1  2.799439e+09
# 10786                   sea captain  2247531869      1  2.247532e+09
# 3341   death of recurring character  2052415039      1  2.052415e+09
# 5430         green goblin character  1921847111      1  1.921847e+09
# 13293                       warthog  1663075401      1  1.663075e+09
# 7640                        meerkat  1663075401      1  1.663075e+09
# 6105                        iceberg  3124776651      2  1.562388e+09
# 10585                  s.h.i.e.l.d.  1520538536      1  1.520539e+09
# 3600                       dogfight  1488732821      1  1.488733e+09
#
#              Median
# 4888   2.923706e+09
# 2942   2.799439e+09
# 10786  2.247532e+09
# 3341   2.052415e+09
# 5430   1.921847e+09
# 13293  1.663075e+09
# 7640   1.663075e+09
# 6105   1.562388e+09
# 10585  1.520539e+09
# 3600   1.488733e+09

# %%
keyword.sort_values(by='Median', ascending=False)[0:10]
# Out:
#                            Keywords       Total  Count          Mean  \
# 4888              forest protection  2923706026      1  2.923706e+09
# 2942                         cosmic  2799439100      1  2.799439e+09
# 10786                   sea captain  2247531869      1  2.247532e+09
# 3341   death of recurring character  2052415039      1  2.052415e+09
# 5430         green goblin character  1921847111      1  1.921847e+09
# 13293                       warthog  1663075401      1  1.663075e+09
# 7640                        meerkat  1663075401      1  1.663075e+09
# 6105                        iceberg  3124776651      2  1.562388e+09
# 10585                  s.h.i.e.l.d.  1520538536      1  1.520539e+09
# 3600                       dogfight  1488732821      1  1.488733e+09
#
#              Median
# 4888   2.923706e+09
# 2942   2.799439e+09
# 10786  2.247532e+09
# 3341   2.052415e+09
# 5430   1.921847e+09
# 13293  1.663075e+09
# 7640   1.663075e+09
# 6105   1.562388e+09
# 10585  1.520539e+09
# 3600   1.488733e+09

# %% [markdown]
# These keywords have high mean and median except the truth that have only 1 count

# %%
count50Keywords = keyword[keyword['Count'] > 20]
count50Keywords.sort_values(by='Mean', ascending=False)
# Out:
#                     Keywords        Total  Count          Mean       Median
# 11997              superhero  35626202921     71  5.017775e+08  366080049.0
# 1151     based on comic book  14855999109     33  4.501818e+08  312136671.0
# 7257                   magic  11929169083     43  2.774225e+08  109676311.0
# 5022                  future   6941091391     26  2.669651e+08  123994398.0
# 6714                    king   6817443780     26  2.622094e+08   58034071.0
# ...                      ...          ...    ...           ...          ...
# 4486        female filmmaker    332313319     32  1.038479e+07    6469740.0
# 12537        timeframe 1960s    243335034     25  9.733401e+06    3359465.0
# 4579   female topless nudity    433010918     45  9.622465e+06    4939939.0
# 4474         female director    445904011     52  8.575077e+06    3335760.0
# 6210        independent film    163013840     32  5.094182e+06    1537836.5
#
# [313 rows x 5 columns]

# %%
count50Keywords.sort_values(by='Mean', ascending=False)[0:30].plot.bar(x='Keywords', y='Mean', color='green')
# Out:
# <AxesSubplot:xlabel='Keywords'>

# %% [markdown]
# **superhero** keywords is popular in the 2010s and have high average gross
#
# Rank keywords

# %%
count50Keywords = count50Keywords.sort_values(by='Mean', ascending=True).reset_index(drop=True)
keywordRank = dict()
for i, row in enumerate(count50Keywords['Keywords']):
    keywordRank[row] = i + 1  ## Plus 1 in order to release the 0 position for another film
keywordRank
# Out:
# {'independent film': 1,
#  'female director': 2,
#  'female topless nudity': 3,
#  'timeframe 1960s': 4,
#  'female filmmaker': 5,
#  'timeframe 1980s': 6,
#  'timeframe 1970s': 7,
#  'satire comedy': 8,
#  'timeframe 1950s': 9,
#  'mistaken identity': 10,
#  'parody comedy': 11,
#  'lesbian': 12,
#  'hood': 13,
#  'written by director': 14,
#  'scene during opening credits': 15,
#  'male frontal nudity': 16,
#  'timeframe 1990s': 17,
#  'two word title': 18,
#  'male rear nudity': 19,
#  'homosexual': 20,
#  'infidelity': 21,
#  'title directed by female': 22,
#  'student': 23,
#  'woman on top': 24,
#  'female frontal nudity': 25,
#  'coming of age': 26,
#  'widow': 27,
#  'african american': 28,
#  'satire': 29,
#  'three word title': 30,
#  'paranoia': 31,
#  'actor': 32,
#  'public nudity': 33,
#  'older woman younger man relationship': 34,
#  'restaurant': 35,
#  'italy': 36,
#  'watching tv': 37,
#  'gay': 38,
#  'male full frontal nudity': 39,
#  'female rear nudity': 40,
#  'prostitute': 41,
#  'period drama': 42,
#  'lust': 43,
#  'vietnam war veteran': 44,
#  '1950s': 45,
#  'money': 46,
#  'painting': 47,
#  'fbi federal bureau of investigation': 48,
#  'jewish': 49,
#  'looking at oneself in a mirror': 50,
#  'marriage': 51,
#  'aerial camera shot': 52,
#  'panties': 53,
#  'character name as title': 54,
#  'reporter': 55,
#  'rape': 56,
#  'coach': 57,
#  'slasher': 58,
#  'male nudity': 59,
#  'teenage girl': 60,
#  'teacher': 61,
#  'farce': 62,
#  'screenplay adapted by author': 63,
#  'femme fatale': 64,
#  'police officer': 65,
#  'love': 66,
#  'nudity': 67,
#  'journalist': 68,
#  'one word title': 69,
#  'adultery': 70,
#  'teenage boy': 71,
#  'bully': 72,
#  'black comedy': 73,
#  'obsession': 74,
#  'breasts': 75,
#  'cigarette': 76,
#  'bar': 77,
#  'neo noir': 78,
#  'pantyhose': 79,
#  'four word title': 80,
#  'car accident': 81,
#  'bound and gagged': 82,
#  'voyeurism': 83,
#  'sex': 84,
#  'voyeur': 85,
#  'boyfriend girlfriend relationship': 86,
#  'bare chested male': 87,
#  'surrealism': 88,
#  'grief': 89,
#  'secret': 90,
#  'gang': 91,
#  'girl': 92,
#  'f rated': 93,
#  'cult film': 94,
#  'hare krishna': 95,
#  'baseball': 96,
#  'female full frontal nudity': 97,
#  'pregnancy': 98,
#  'actress': 99,
#  'boy': 100,
#  'london england': 101,
#  'female nudity': 102,
#  'dysfunctional family': 103,
#  'sex comedy': 104,
#  'high school': 105,
#  'small town': 106,
#  'character names as title': 107,
#  'pubic hair': 108,
#  'voice over narration': 109,
#  'family relationships': 110,
#  'seduction': 111,
#  'drugs': 112,
#  'doctor': 113,
#  'sex scene': 114,
#  'writer': 115,
#  'husband wife relationship': 116,
#  'character name in title': 117,
#  'suicide': 118,
#  'priest': 119,
#  'american abroad': 120,
#  'bikini': 121,
#  'man wears eyeglasses': 122,
#  'slimehouse': 123,
#  'concert': 124,
#  'boxing': 125,
#  '1930s': 126,
#  'college': 127,
#  'extramarital affair': 128,
#  'friend': 129,
#  'sex in bed': 130,
#  'prison': 131,
#  'road trip': 132,
#  'serial killer': 133,
#  'dance': 134,
#  'child in jeopardy': 135,
#  'school': 136,
#  'gangster': 137,
#  'columbia tristar': 138,
#  'neo screwball comedy': 139,
#  'singer': 140,
#  'france': 141,
#  'lawyer': 142,
#  'basketball': 143,
#  'spoof': 144,
#  'blonde': 145,
#  '3d': 146,
#  'love triangle': 147,
#  'airport': 148,
#  'politics': 149,
#  'psychotronic film': 150,
#  'criminal': 151,
#  'texas': 152,
#  'flashback': 153,
#  '1960s': 154,
#  'nightmare': 155,
#  'paris france': 156,
#  'neighbor': 157,
#  'military': 158,
#  'brother brother relationship': 159,
#  'vietnam': 160,
#  'vietnam war': 161,
#  'nightclub': 162,
#  'new york city': 163,
#  'fbi agent': 164,
#  'slapstick comedy': 165,
#  'mafia': 166,
#  'murder': 167,
#  '1970s': 168,
#  'best friend': 169,
#  'cancer': 170,
#  '1920s': 171,
#  'psychopath': 172,
#  'road movie': 173,
#  'detective': 174,
#  '1990s': 175,
#  'shootout': 176,
#  'funeral': 177,
#  'teenager': 178,
#  'vigilante': 179,
#  'stripper': 180,
#  '1980s': 181,
#  'investigation': 182,
#  'desert': 183,
#  '1940s': 184,
#  'church': 185,
#  'dancing': 186,
#  'based on true story': 187,
#  'nazi': 188,
#  'racism': 189,
#  'based on real person': 190,
#  'torture': 191,
#  'time bomb': 192,
#  'dream': 193,
#  'hitman': 194,
#  'new york': 195,
#  'horse': 196,
#  'fish out of water': 197,
#  'mother daughter relationship': 198,
#  'musician': 199,
#  'casino': 200,
#  'hostage': 201,
#  'rivalry': 202,
#  'mother son relationship': 203,
#  'undercover': 204,
#  'los angeles california': 205,
#  'baby': 206,
#  'disney': 207,
#  'police': 208,
#  'india': 209,
#  'revenge': 210,
#  'singing in a car': 211,
#  'strong female character': 212,
#  'hospital': 213,
#  'brother sister relationship': 214,
#  'kiss': 215,
#  'farm': 216,
#  'vomiting': 217,
#  'train': 218,
#  'father daughter relationship': 219,
#  'father son relationship': 220,
#  'escape': 221,
#  'japan': 222,
#  'on the run': 223,
#  'supernatural horror': 224,
#  'violence': 225,
#  'parody': 226,
#  'christmas': 227,
#  'boat': 228,
#  'beach': 229,
#  'single mother': 230,
#  'divorce': 231,
#  'snow': 232,
#  'party': 233,
#  'on the road': 234,
#  'dog': 235,
#  'scantily clad female': 236,
#  'cat': 237,
#  'male protagonist': 238,
#  'fight': 239,
#  'soldier': 240,
#  'conspiracy': 241,
#  'female protagonist': 242,
#  'hotel': 243,
#  'mexico': 244,
#  'zombie': 245,
#  'vacation': 246,
#  'hero': 247,
#  'singing': 248,
#  'chase': 249,
#  'based on novel': 250,
#  'wedding': 251,
#  'blood': 252,
#  'friendship': 253,
#  '2000s': 254,
#  'california': 255,
#  'deception': 256,
#  'kidnapping': 257,
#  '2010s': 258,
#  'demon': 259,
#  'no opening credits': 260,
#  'car': 261,
#  'heist': 262,
#  'scientist': 263,
#  'terrorist': 264,
#  'robot': 265,
#  'rescue': 266,
#  'sister sister relationship': 267,
#  'martial arts': 268,
#  'class differences': 269,
#  'ghost': 270,
#  'africa': 271,
#  'world war two': 272,
#  'con artist': 273,
#  'younger version of character': 274,
#  'survival': 275,
#  'good versus evil': 276,
#  'remake': 277,
#  '3 dimensional': 278,
#  'death': 279,
#  'teen movie': 280,
#  'orphan': 281,
#  'island': 282,
#  'vampire': 283,
#  'supernatural power': 284,
#  'dystopia': 285,
#  'memory': 286,
#  'race against time': 287,
#  'gun': 288,
#  'post apocalypse': 289,
#  'china': 290,
#  'assassin': 291,
#  'outer space': 292,
#  'monster': 293,
#  'witch': 294,
#  'alien': 295,
#  'snow adventure': 296,
#  'spy': 297,
#  'astronaut': 298,
#  'villain': 299,
#  'artificial intelligence': 300,
#  'action hero': 301,
#  'based on video game': 302,
#  'betrayal': 303,
#  'time travel': 304,
#  'princess': 305,
#  'jungle': 306,
#  'sequel': 307,
#  'second part': 308,
#  'king': 309,
#  'future': 310,
#  'magic': 311,
#  'based on comic book': 312,
#  'superhero': 313}

# %% [markdown]
# Get rank for keywords by maximum
#
# Default max rank = 0

# %%
import random


def getKeywordsRank(keywords):
    max = 0
    for keyword in keywords:
        if keyword not in keywordRank.keys():
            continue
        if keywordRank[keyword] > max:
            max = keywordRank[keyword]
    if max == 0:
        max = random.randint(1, 100)
    return max


data2 = data.copy()
data2['keywordRank'] = data2['Keywords'].apply(getKeywordsRank)
corr = pearsonr(data2['keywordRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between keywordRank and Gross: %.3f' % corr)
data2.plot.scatter(x='keywordRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between keywordRank and Gross: 0.178
# <AxesSubplot:xlabel='keywordRank', ylabel='Gross_worldwide'>

# %%
import random


def getKeywordsRank(keywords):
    total = 0
    length = len(keywords)
    if length == 0:
        length = 1
    for keyword in keywords:
        if keyword not in keywordRank.keys():
            total += random.randint(1, 100)
            continue
        total += keywordRank[keyword]
    return total / length


data2 = data.copy()
data2['keywordRank'] = data2['Keywords'].apply(getKeywordsRank)
corr = pearsonr(data2['keywordRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between keywordRank and Gross: %.3f' % corr)
data2.plot.scatter(x='keywordRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between keywordRank and Gross: 0.176
# <AxesSubplot:xlabel='keywordRank', ylabel='Gross_worldwide'>

# %%
final['keywordRank'] = data2['keywordRank']

# %% [markdown]
# ## MPAA Analysis
#
# How distribution of gross by MPAA Certificate

# %%
certificate = parseWithMoneyAndCount(data, 'ListOfCertificate')
fig = plt.figure(figsize=(8, 4))
data2 = certificate.sort_values(by='Count', ascending=False)
plt.bar(data=data2, x='ListOfCertificate', height='Count', color="salmon")
plt.xticks(rotation=90, fontsize=15)
plt.ylabel("Count", fontsize=20)
plt.title("Releases By Certificate", fontsize=20)
plt.show()
fig = plt.figure(figsize=(8, 4))
data2 = certificate.sort_values(by='Median', ascending=False)
plt.bar(data=data2, x='ListOfCertificate', height='Median', color="salmon")
plt.xticks(rotation=90, fontsize=15)
plt.ylabel("Median Gross", fontsize=20)
plt.title("Gross By Certificate", fontsize=20)
plt.show()
fig = plt.figure(figsize=(8, 4))
data2 = certificate.sort_values(by='Mean', ascending=False)
plt.bar(data=data2, x='ListOfCertificate', height='Mean', color="salmon")
plt.xticks(rotation=90, fontsize=15)
plt.ylabel("Mean Gross", fontsize=20)
plt.title("Gross By Certificate", fontsize=20)
plt.show()

# %% [markdown]
# NC-17 has the least numbers of release

# %% [markdown]
# PG-13 and G has higher mean and medians gross
# R and NC-27 has low mean and median gross
# This is understandable since R and NC-27 will reduces the age can watch the film. Hence lower!

# %%
certificate
# Out:
#   ListOfCertificate         Total  Count          Mean      Median
# 0                 G   42918674597    928  4.624857e+07   6801135.0
# 1             NC-17     725325710     37  1.960340e+07   7412216.0
# 2                PG  148336892546   1639  9.050451e+07  23840350.0
# 3             PG-13  300264785098   2482  1.209769e+08  37175371.0
# 4                 R  172084539697   3834  4.488381e+07  14509365.5

# %% [markdown]
# Conduct rank by Certificate
#
# By Mean

# %%
certificate = certificate.sort_values(by='Mean', ascending=True).reset_index(drop=True)
cerRank = dict()
for i, row in enumerate(certificate['ListOfCertificate']):
    cerRank[row] = i + 1
cerRank
# Out:
# {'NC-17': 1, 'R': 2, 'G': 3, 'PG': 4, 'PG-13': 5}

# %%
def getCerRank(cers):
    max = 0
    for cer in cers:
        if cer not in cerRank.keys():
            continue
        if cerRank[cer] > max:
            max = cerRank[cer]
    return max


data2 = data.copy()
data2['cerRank'] = data2['ListOfCertificate'].apply(getCerRank)
corr = pearsonr(data2['cerRank'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between cerRank and Gross: %.3f' % corr)
data2.plot.scatter(x='cerRank', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between cerRank and Gross: 0.204
# <AxesSubplot:xlabel='cerRank', ylabel='Gross_worldwide'>

# %%
final['cerRank'] = data2['cerRank']

# %% [markdown]
# See that PG-13 have the highest mean gross.
#
# We will test that is movie have rated PG-13 will have more gross than others.

# %%
data2 = data.copy()
data2['PG-13'] = data2['ListOfCertificate'].apply(lambda x: 1 if 'PG-13' in x else 0)
corr = pearsonr(data2['PG-13'], data2['Gross_worldwide'])[0]
print('Pearsons correlation between PG-13 and Gross: %.3f' % corr)
data2.plot.scatter(x='PG-13', y='Gross_worldwide', color='blue')
# Out:
# Pearsons correlation between PG-13 and Gross: 0.180
# <AxesSubplot:xlabel='PG-13', ylabel='Gross_worldwide'>

# %% [markdown]
# ## Export to CSV

# %%
final.to_csv('../dataset/extracted/feature_extracted.csv', index=False)
